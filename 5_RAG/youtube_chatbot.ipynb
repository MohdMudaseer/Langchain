# %%
import re
from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled

def extract_videoID(url):
    """
    Extracts the 11-character YouTube video ID from a URL.
    Returns video ID (string) or None if no ID is found.
    """
    match = re.search(r"(?:v=|\/)([0-9A-Za-z_-]{11})", url)
    if match:
        return match.group(1)
    return None

url = input("Youtube URL:\n")
video_id = extract_videoID(url)

try:
    ytt_api = YouTubeTranscriptApi()
    # If you don’t care which language, this returns the “best” one
    transcript_list = ytt_api.fetch(video_id, languages=['en'])
    transcript_list = transcript_list.to_raw_data()

    # Flatten it to plain text
    transcript = " ".join(chunk["text"] for chunk in transcript_list)
    print(transcript)
except TranscriptsDisabled:
    print("No Transcripts available")
# Out:
# I learned how to use Notebook LM for you. So, here's the Cliffnotes version to save you the hours and hours that I've spent deep diving into this extremely powerful tool for both working and learning. It is honestly one of my favorite tools, and it's crazy how much value you get from the free version. So, in this video, I'm going to show you the core features of Notebook Outlook, including things like distilling and summarizing information and how to make it even more powerful in combination with other tools to even do things like automating workflows and building AI products. As per usual, it is not enough for you just to listen to me talk about stuff. So throughout this video, I will have little assessments which if you can answer these questions, then congratulations. You would be educated on using Notebook LM. Now, without further ado, let's go. A portion of this video is sponsored by Augen Code. Let's start off with first answering the question, what is Notebook LM for? Well, if you go to the landing page for Notebook LM, there in big massive letters, it says understand anything. The core kind of concept of notebook LM is that in our information age, the problem is not the lack of knowledge. It's our ability to understand and make sense of it. And that is what notebook LM is here to do. It allows you to take a lot of different types of information from a lot of different sources, synthesize them together, and help you understand them deeply. I'll go through each feature of Notebook LM in detail in just a little bit, but first I want to explain the overarching workflow for Notebook Lab. When you first go into Notebook LM and you click create a new notebook, step number one is to upload your sources. You can drag and drop all sorts of different files and also link from your Google Drive, different links including websites and YouTube links and copy text as well. You can also click to discover sources tab and be able to search other external sources too. You can then chat with your sources in this chat window asking you to do things like summarizing or analyzing. But that's not all. What really makes Notebook LM stand out are these specialized sources here under studio to help you dive deeper into the content and to understand it better, including things like generating an audio overview, generating an AI podcast. Today, we're diving headirst into something which is what first made Notebook LM go viral, and also do video overviews, mind maps, and all sorts of reports. I'll be showing you examples of these all in a bit, and it is really, really cool. As its name suggests, Notebook LM is also a note-taking application. So, it allows you to add a note and include your own notes. And finally, there are sharing features and analytics features which are paid pro features. But like 90% of notebookm is completely free. This primary workflow is already extremely powerful. But if you combine it together with other applications like Google AI studio or Firebase Studio, which are also both free Google products, you can make it even more powerful to build entire workflows and apps. And you don't even need to know how to code. All right. Now you have a good general overview of the setup for Notebook LM. Let's now cover each of these features in detail. Starting off by adding some sources. I am interested in building a vertical AI agent app or learning languages. And I want notebook LM to help me figure out what I should be building, including things like analyzing industry trends, different pain points, brainstorming and validating different ideas before coming to a four set of features to build for my MVP, my minimal viable product. This is a report from OECD on the trends shaping education 2025. Um, and this is a very very reputable report about the education space. So I'm going to add that as a source. I'm also going to add a couple YouTube videos. This is one from Y Combinator about how to build AI agents, how to validate startup idea ...

# %%
transcript_list
# Out:
# [{'text': 'I learned how to use Notebook LM for',
#   'start': 0.0,
#   'duration': 3.52},
#  {'text': "you. So, here's the Cliffnotes version",
#   'start': 1.68,
#   'duration': 3.52},
#  {'text': 'to save you the hours and hours that',
#   'start': 3.52,
#   'duration': 3.759},
#  {'text': "I've spent deep diving into this", 'start': 5.2, 'duration': 4.24},
#  {'text': 'extremely powerful tool for both working',
#   'start': 7.279,
#   'duration': 4.001},
#  {'text': 'and learning. It is honestly one of my',
#   'start': 9.44,
#   'duration': 3.52},
#  {'text': "favorite tools, and it's crazy how much",
#   'start': 11.28,
#   'duration': 3.92},
#  {'text': 'value you get from the free version. So,',
#   'start': 12.96,
#   'duration': 3.44},
#  {'text': "in this video, I'm going to show you the",
#   'start': 15.2,
#   'duration': 2.88},
#  {'text': 'core features of Notebook Outlook,',
#   'start': 16.4,
#   'duration': 2.959},
#  {'text': 'including things like distilling and',
#   'start': 18.08,
#   'duration': 3.039},
#  {'text': 'summarizing information and how to make',
#   'start': 19.359,
#   'duration': 3.521},
#  {'text': 'it even more powerful in combination',
#   'start': 21.119,
#   'duration': 3.521},
#  {'text': 'with other tools to even do things like',
#   'start': 22.88,
#   'duration': 3.76},
#  {'text': 'automating workflows and building AI',
#   'start': 24.64,
#   'duration': 3.6},
#  {'text': 'products. As per usual, it is not enough',
#   'start': 26.64,
#   'duration': 3.039},
#  {'text': 'for you just to listen to me talk about',
#   'start': 28.24,
#   'duration': 3.119},
#  {'text': 'stuff. So throughout this video, I will',
#   'start': 29.679,
#   'duration': 3.441},
#  {'text': 'have little assessments which if you can',
#   'start': 31.359,
#   'duration': 2.961},
#  {'text': 'answer these questions, then', 'start': 33.12, 'duration': 2.8},
#  {'text': 'congratulations. You would be educated',
#   'start': 34.32,
#   'duration': 3.68},
#  {'text': 'on using Notebook LM. Now, without',
#   'start': 35.92,
#   'duration': 4.0},
#  {'text': "further ado, let's go. A portion of this",
#   'start': 38.0,
#   'duration': 3.76},
#  {'text': "video is sponsored by Augen Code. Let's",
#   'start': 39.92,
#   'duration': 3.12},
#  {'text': 'start off with first answering the',
#   'start': 41.76,
#   'duration': 3.68},
#  {'text': 'question, what is Notebook LM for? Well,',
#   'start': 43.04,
#   'duration': 3.76},
#  {'text': 'if you go to the landing page for',
#   'start': 45.44,
#   'duration': 3.599},
#  {'text': 'Notebook LM, there in big massive', 'start': 46.8, 'duration': 4.4},
#  {'text': 'letters, it says understand anything.',
#   'start': 49.039,
#   'duration': 4.801},
#  {'text': 'The core kind of concept of notebook LM',
#   'start': 51.2,
#   'duration': 4.96},
#  {'text': 'is that in our information age, the',
#   'start': 53.84,
#   'duration': 4.399},
#  {'text': 'problem is not the lack of knowledge.',
#   'start': 56.16,
#   'duration': 4.399},
#  {'text': "It's our ability to understand and make",
#   'start': 58.239,
#   'duration': 4.32},
#  {'text': 'sense of it. And that is what notebook',
#   'start': 60.559,
#   'duration': 4.481},
#  {'text': 'LM is here to do. It allows you to take',
#   'start': 62.559,
#   'duration': 3.92},
#  {'text': 'a lot of different types of information',
#   'start': 65.04,
#   'duration': 3.119},
#  {'text': 'from a lot of different sources,',
#   'start': 66.479,
#   'duration': 3.361},
#  {'text': 'synthesize them together, and help you',
#   'start': 68.159,
#   'duration': 3.28},
#  {'text': "understand them deeply. I'll go through",
#   'start': 69.84,
#   'duration': 3.84},
#  {'text': 'each feature of Notebook LM in detail in',
#   'start': 71.439,
#   'duration': 4.0},
#  {'text': 'just a little bit, but first I want to',
#   'start': 73.68,
#   'duration': 3.68},
#  {'text': 'explain the overarching workflow for',
#   'start': 75.439,
#   'duration': 3.521},
#  {'text': 'Notebook Lab. When you first go into',
#   'start': 77.36,
#   'duration': 3.36},
#  {'text': 'Notebook LM and you click create a new',
#   'start': 78.96,
#   'duration': 3.839},
#  {'text': 'notebook, step number one is to upload',
#   'start': 80.72,
#   'duration': 3.84},
#  {'text': 'your sources. You can drag and drop all',
#   'start': 82.799,
#   'duration': 3.441},
#  {'text': 'sorts of different files and also link',
#   'start': 84.56,
#   'duration': 3.599},
#  {'text': 'from your Google Drive, different links',
#   'start': 86.24,
#   'duration': 3.76},
#  {'text': 'including websites and YouTube links and',
#   'start': 88.159,
#   'duration': 3.761},
#  {'text': 'copy text as well. You can also click to',
#   'start': 90.0,
#   'duration': 3.759},
#  {'text': 'discover sources tab and be able to',
#   'start': 91.92,
#   'duration': 3.68},
#  {'text': 'search other external sources too. You',
#   'start': 93.759,
#   'duration': 3.441},
#  {'text': 'can then chat with your sources in this',
#   'start': 95.6,
#   'duration': 3.36},
#  {'text': 'chat window asking you to do things like',
#   'start': 97.2,
#   'duration': 4.0},
#  {'text': "summarizing or analyzing. But that's not",
#   'start': 98.96,
#   'duration': 4.4},
#  {'text': 'all. What really makes Notebook LM stand',
#   'start': 101.2,
#   'duration': 4.559},
#  {'text': 'out are these specialized sources here',
#   'start': 103.36,
#   'duration': 4.0},
#  {'text': 'under studio to help you dive deeper',
#   'start': 105.759,
#   'duration': 3.121},
#  {'text': 'into the content and to understand it',
#   'start': 107.36,
#   'duration': 2.799},
#  {'text': 'better, including things like generating',
#   'start': 108.88,
#   'duration': 2.96},
#  {'text': 'an audio overview, generating an AI',
#   'start': 110.159,
#   'duration': 2.24},
#  {'text': 'podcast.', 'start': 111.84, 'duration': 2.88},
#  {'text': "Today, we're diving headirst into",
#   'start': 112.399,
#   'duration': 3.04},
#  {'text': 'something', 'start': 114.72, 'duration': 2.88},
#  {'text': 'which is what first made Notebook LM go',
#   'start': 115.439,
#   'duration': 4.161},
#  {'text': 'viral, and also do video overviews, mind',
#   'start': 117.6,
#   'duration': 3.76},
#  {'text': "maps, and all sorts of reports. I'll be",
#   'start': 119.6,
#   'duration': 3.28},
#  {'text': 'showing you examples of these all in a',
#   'start': 121.36,
#   'duration': 3.2},
#  {'text': 'bit, and it is really, really cool. As',
#   'start': 122.88,
#   'duration': 3.76},
#  {'text': 'its name suggests, Notebook LM is also a',
#   'start': 124.56,
#   'duration': 3.839},
#  {'text': 'note-taking application. So, it allows',
#   'start': 126.64,
#   'duration': 3.599},
#  {'text': 'you to add a note and include your own',
#   'start': 128.399,
#   'duration': 3.681},
#  {'text': 'notes. And finally, there are sharing',
#   'start': 130.239,
#   'duration': 3.681},
#  {'text': 'features and analytics features which',
#   'start': 132.08,
#   'duration': 4.64},
#  {'text': 'are paid pro features. But like 90% of',
#   'start': 133.92,
#   'duration': 4.8},
#  {'text': 'notebookm is completely free. This',
#   'start': 136.72,
#   'duration': 3.92},
#  {'text': 'primary workflow is already extremely',
#   'start': 138.72,
#   'duration': 3.92},
#  {'text': 'powerful. But if you combine it together',
#   'start': 140.64,
#   'duration': 4.16},
#  {'text': 'with other applications like Google AI',
#   'start': 142.64,
#   'duration': 3.76},
#  {'text': 'studio or Firebase Studio, which are',
#   'start': 144.8,
#   'duration': 3.439},
#  {'text': 'also both free Google products, you can',
#   'start': 146.4,
#   'duration': 3.44},
#  {'text': 'make it even more powerful to build',
#   'start': 148.239,
#   'duration': 3.521},
#  {'text': "entire workflows and apps. And you don't",
#   'start': 149.84,
#   'duration': 2.88},
#  {'text': 'even need to know how to code. All',
#   'start': 151.76,
#   'duration': 2.64},
#  {'text': 'right. Now you have a good general',
#   'start': 152.72,
#   'duration': 3.76},
#  {'text': 'overview of the setup for Notebook LM.',
#   'start': 154.4,
#   'duration': 3.68},
#  {'text': "Let's now cover each of these features",
#   'start': 156.48,
#   'duration': 3.68},
#  {'text': 'in detail. Starting off by adding some',
#   'start': 158.08,
#   'duration': 4.239},
#  {'text': 'sources. I am interested in building a',
#   'start': 160.16,
#   'duration': 3.92},
#  {'text': 'vertical AI agent app or learning',
#   'start': 162.319,
#   'duration': 3.521},
#  {'text': 'languages. And I want notebook LM to',
#   'start': 164.08,
#   'duration': 2.799},
#  {'text': 'help me figure out what I should be',
#   'start': 165.84,
#   'duration': 2.0},
#  {'text': 'building, including things like',
#   'start': 166.879,
#   'duration': 2.72},
#  {'text': 'analyzing industry trends, different',
#   'start': 167.84,
#   'duration': 3.28},
#  {'text': 'pain points, brainstorming and',
#   'start': 169.599,
#   'duration': 3.36},
#  {'text': 'validating different ideas before coming',
#   'start': 171.12,
#   'duration': 4.479},
#  {'text': 'to a four set of features to build for',
#   'start': 172.959,
#   'duration': 5.041},
#  {'text': 'my MVP, my minimal viable product. This',
#   'start': 175.599,
#   'duration': 4.72},
#  {'text': 'is a report from OECD on the trends',
#   'start': 178.0,
#   'duration': 4.72},
#  {'text': 'shaping education 2025. Um, and this is',
#   'start': 180.319,
#   'duration': 5.601},
#  {'text': 'a very very reputable report about the',
#   'start': 182.72,
#   'duration': 4.72},
#  {'text': "education space. So I'm going to add",
#   'start': 185.92,
#   'duration': 3.599},
#  {'text': "that as a source. I'm also going to add",
#   'start': 187.44,
#   'duration': 3.92},
#  {'text': 'a couple YouTube videos. This is one',
#   'start': 189.519,
#   'duration': 4.161},
#  {'text': 'from Y Combinator about how to build AI',
#   'start': 191.36,
#   'duration': 4.32},
#  {'text': 'agents, how to validate startup ideas.',
#   'start': 193.68,
#   'duration': 3.839},
#  {'text': 'So notebook alum can help me with that',
#   'start': 195.68,
#   'duration': 3.6},
#  {'text': 'as well as an article which is very',
#   'start': 197.519,
#   'duration': 4.0},
#  {'text': 'popular for startup founders. Then I',
#   'start': 199.28,
#   'duration': 4.72},
#  {'text': 'will copy some text which is what I got',
#   'start': 201.519,
#   'duration': 4.8},
#  {'text': 'from a deep research over here from',
#   'start': 204.0,
#   'duration': 4.319},
#  {'text': 'Google Gemini that goes into a deep dive',
#   'start': 206.319,
#   'duration': 3.761},
#  {'text': 'of the competitor analysis of the',
#   'start': 208.319,
#   'duration': 3.84},
#  {'text': 'education space including the core SAS',
#   'start': 210.08,
#   'duration': 3.76},
#  {'text': 'competitors in the space. Later in the',
#   'start': 212.159,
#   'duration': 2.961},
#  {'text': "video, I'll be going into more detail",
#   'start': 213.84,
#   'duration': 2.88},
#  {'text': 'about how to use other applications like',
#   'start': 215.12,
#   'duration': 3.199},
#  {'text': 'deep research in order to get really',
#   'start': 216.72,
#   'duration': 2.96},
#  {'text': 'good sources. But for now, I just want',
#   'start': 218.319,
#   'duration': 2.56},
#  {'text': 'to show you all the different types of',
#   'start': 219.68,
#   'duration': 2.88},
#  {'text': 'sources that notebook elm can take,',
#   'start': 220.879,
#   'duration': 3.92},
#  {'text': 'including this copied text information.',
#   'start': 222.56,
#   'duration': 3.759},
#  {'text': "But that's not all. I also want to click",
#   'start': 224.799,
#   'duration': 3.921},
#  {'text': 'the discover button here to search for',
#   'start': 226.319,
#   'duration': 4.241},
#  {'text': 'additional sources that I think will be',
#   'start': 228.72,
#   'duration': 3.68},
#  {'text': 'useful in this task. To get a better',
#   'start': 230.56,
#   'duration': 3.52},
#  {'text': 'understanding of customer pain points, I',
#   'start': 232.4,
#   'duration': 3.839},
#  {'text': 'wrote look at a variety of UGC user',
#   'start': 234.08,
#   'duration': 3.76},
#  {'text': 'generated content sources including',
#   'start': 236.239,
#   'duration': 3.441},
#  {'text': 'Reddit Xora defined painoints and',
#   'start': 237.84,
#   'duration': 3.92},
#  {'text': 'language learning education space. Click',
#   'start': 239.68,
#   'duration': 4.8},
#  {'text': "submit. And I'm going to add all these",
#   'start': 241.76,
#   'duration': 4.72},
#  {'text': 'Reddit sources, but not this one because',
#   'start': 244.48,
#   'duration': 4.16},
#  {'text': "I'm more interested in user generated",
#   'start': 246.48,
#   'duration': 4.24},
#  {'text': 'content, not academic perspectives. So',
#   'start': 248.64,
#   'duration': 4.319},
#  {'text': "I'll click import. Rename them by typing",
#   'start': 250.72,
#   'duration': 3.92},
#  {'text': 'user in the beginning. So I know that',
#   'start': 252.959,
#   'duration': 4.721},
#  {'text': "these are about users pain points. I'll",
#   'start': 254.64,
#   'duration': 5.76},
#  {'text': 'name these previous ones evaluate',
#   'start': 257.68,
#   'duration': 4.48},
#  {'text': "because it's for evaluating different",
#   'start': 260.4,
#   'duration': 3.84},
#  {'text': "startup ideas. And we'll call this one",
#   'start': 262.16,
#   'duration': 3.52},
#  {'text': "trends because it's about industry",
#   'start': 264.24,
#   'duration': 3.679},
#  {'text': 'trends. I also want to search and add a',
#   'start': 265.68,
#   'duration': 4.4},
#  {'text': 'few more sources on industry trends.',
#   'start': 267.919,
#   'duration': 4.56},
#  {'text': 'Always good to take a look as well on',
#   'start': 270.08,
#   'duration': 4.24},
#  {'text': 'what it comes up with. Okay, this looks',
#   'start': 272.479,
#   'duration': 3.521},
#  {'text': "legit because it's a study. And we'll",
#   'start': 274.32,
#   'duration': 3.68},
#  {'text': 'add a couple more sources. Moving on to',
#   'start': 276.0,
#   'duration': 3.919},
#  {'text': 'the chat interface. It already gives you',
#   'start': 278.0,
#   'duration': 4.24},
#  {'text': 'a little overview over here. But I do',
#   'start': 279.919,
#   'duration': 3.84},
#  {'text': 'want to dive deeper. Starting off with a',
#   'start': 282.24,
#   'duration': 3.04},
#  {'text': 'better understanding of the industry',
#   'start': 283.759,
#   'duration': 3.201},
#  {'text': "trends specifically. So, I'm actually",
#   'start': 285.28,
#   'duration': 3.52},
#  {'text': 'going to uncheck everything except for',
#   'start': 286.96,
#   'duration': 4.16},
#  {'text': 'the industry trends and ask it to',
#   'start': 288.8,
#   'duration': 5.2},
#  {'text': 'summarize the industry trends for',
#   'start': 291.12,
#   'duration': 5.84},
#  {'text': 'language learning. Click enter. And it',
#   'start': 294.0,
#   'duration': 4.639},
#  {'text': 'gives us a little summary talking about',
#   'start': 296.96,
#   'duration': 3.2},
#  {'text': 'the language learning app market is',
#   'start': 298.639,
#   'duration': 3.28},
#  {'text': 'experiencing rapid expansion influenced',
#   'start': 300.16,
#   'duration': 3.2},
#  {'text': 'by several key trends, drivers,',
#   'start': 301.919,
#   'duration': 3.921},
#  {'text': 'restraints and opportunities, key market',
#   'start': 303.36,
#   'duration': 4.32},
#  {'text': 'insights and drivers blah blah blah. It',
#   'start': 305.84,
#   'duration': 3.76},
#  {'text': "also gives you the sources where it's",
#   'start': 307.68,
#   'duration': 4.16},
#  {'text': 'coming from. So you can actually um very',
#   'start': 309.6,
#   'duration': 4.24},
#  {'text': 'easily double check and click into this',
#   'start': 311.84,
#   'duration': 3.28},
#  {'text': 'as well. This is one of the main',
#   'start': 313.84,
#   'duration': 2.88},
#  {'text': 'functionalities of notebook LM because',
#   'start': 315.12,
#   'duration': 3.68},
#  {'text': "it's so grounded in the sources that",
#   'start': 316.72,
#   'duration': 4.16},
#  {'text': "it's being provided. This has much less",
#   'start': 318.8,
#   'duration': 4.32},
#  {'text': 'room for hallucinations. So yeah, key',
#   'start': 320.88,
#   'duration': 3.92},
#  {'text': 'market insights and drivers, market',
#   'start': 323.12,
#   'duration': 4.96},
#  {'text': 'segmentation by type, by application, by',
#   'start': 324.8,
#   'duration': 6.0},
#  {'text': 'language, okay, and by geography. So I',
#   'start': 328.08,
#   'duration': 4.16},
#  {'text': 'want to ask some questions like what',
#   'start': 330.8,
#   'duration': 5.119},
#  {'text': 'about AI first language learning apps',
#   'start': 332.24,
#   'duration': 7.519},
#  {'text': 'versus traditional SAS apps cuz I want',
#   'start': 335.919,
#   'duration': 5.601},
#  {'text': 'to build something that is an AI first',
#   'start': 339.759,
#   'duration': 4.72},
#  {'text': 'like vertical agent um application. Who',
#   'start': 341.52,
#   'duration': 6.32},
#  {'text': 'are the industry leaders here and where',
#   'start': 344.479,
#   'duration': 6.081},
#  {'text': 'are the gaps? So it says in AI language',
#   'start': 347.84,
#   'duration': 4.0},
#  {'text': 'learning app the market growth is',
#   'start': 350.56,
#   'duration': 2.56},
#  {'text': 'largely fueled by advancements in',
#   'start': 351.84,
#   'duration': 3.04},
#  {'text': "digital education technology. So it's",
#   'start': 353.12,
#   'duration': 3.68},
#  {'text': 'showing that Dualingo for example is',
#   'start': 354.88,
#   'duration': 3.84},
#  {'text': 'introducing AIdriven custom lessons and',
#   'start': 356.8,
#   'duration': 4.16},
#  {'text': 'realtime voice recognition. And you can',
#   'start': 358.72,
#   'duration': 3.759},
#  {'text': 'see that it would actually just tell you',
#   'start': 360.96,
#   'duration': 2.959},
#  {'text': 'that the provided sources do not',
#   'start': 362.479,
#   'duration': 2.881},
#  {'text': 'explicitly differentiate between AI',
#   'start': 363.919,
#   'duration': 3.201},
#  {'text': 'versus traditional SAS apps. So it',
#   'start': 365.36,
#   'duration': 3.36},
#  {'text': 'really is grounded in the sources that',
#   'start': 367.12,
#   'duration': 4.0},
#  {'text': 'you provide. But it does show you all of',
#   'start': 368.72,
#   'duration': 4.479},
#  {'text': 'the different competitors that are in',
#   'start': 371.12,
#   'duration': 4.0},
#  {'text': 'the market right now and gaps in the',
#   'start': 373.199,
#   'duration': 3.601},
#  {'text': 'market where AI could be able to help',
#   'start': 375.12,
#   'duration': 3.68},
#  {'text': 'with. Very interesting. So before we',
#   'start': 376.8,
#   'duration': 3.2},
#  {'text': 'move forward, make sure that you do',
#   'start': 378.8,
#   'duration': 3.28},
#  {'text': "click save to notes because if you don't",
#   'start': 380.0,
#   'duration': 3.759},
#  {'text': 'do this, all of this is actually going',
#   'start': 382.08,
#   'duration': 3.679},
#  {'text': 'to disappear because notebook has a',
#   'start': 383.759,
#   'duration': 3.681},
#  {'text': "privacy policy where it doesn't actually",
#   'start': 385.759,
#   'duration': 3.841},
#  {'text': "save the chat history and it doesn't",
#   'start': 387.44,
#   'duration': 4.08},
#  {'text': 'train on it as well. Okay, cool. Going',
#   'start': 389.6,
#   'duration': 4.4},
#  {'text': 'to do something similar for the user',
#   'start': 391.52,
#   'duration': 5.28},
#  {'text': 'pain points. Summarize the user pain',
#   'start': 394.0,
#   'duration': 5.199},
#  {'text': 'points and we can see some of the key',
#   'start': 396.8,
#   'duration': 4.16},
#  {'text': 'pain points including effectiveness and',
#   'start': 399.199,
#   'duration': 3.361},
#  {'text': 'fluency challenge. Many language',
#   'start': 400.96,
#   'duration': 3.2},
#  {'text': 'learning applications are perceived as',
#   'start': 402.56,
#   'duration': 3.359},
#  {'text': 'failing to lead to true fluency, depth',
#   'start': 404.16,
#   'duration': 3.52},
#  {'text': 'or mastery, motivation, engagement,',
#   'start': 405.919,
#   'duration': 3.28},
#  {'text': 'constant accessibility of traditional',
#   'start': 407.68,
#   'duration': 3.68},
#  {'text': 'methods, fear of mistakes, etc., etc.',
#   'start': 409.199,
#   'duration': 4.241},
#  {'text': 'Also, make sure to save to note here so',
#   'start': 411.36,
#   'duration': 4.16},
#  {'text': "we don't end up losing that information.",
#   'start': 413.44,
#   'duration': 3.36},
#  {'text': 'So, you should continue doing this and',
#   'start': 415.52,
#   'duration': 2.64},
#  {'text': 'asking more questions and learning more',
#   'start': 416.8,
#   'duration': 3.04},
#  {'text': 'from these sources. But I want to draw',
#   'start': 418.16,
#   'duration': 4.159},
#  {'text': 'your attention now to the studio section',
#   'start': 419.84,
#   'duration': 4.079},
#  {'text': 'where there are also other features to',
#   'start': 422.319,
#   'duration': 3.041},
#  {'text': 'help you understand this content better.',
#   'start': 423.919,
#   'duration': 2.641},
#  {'text': 'This is one of my favorite ones called',
#   'start': 425.36,
#   'duration': 3.04},
#  {'text': "the audio overview. So, let's click this",
#   'start': 426.56,
#   'duration': 4.0},
#  {'text': 'and it will generate an AI podcast',
#   'start': 428.4,
#   'duration': 4.799},
#  {'text': 'specifically for the user pain points',
#   'start': 430.56,
#   'duration': 5.52},
#  {'text': 'that we selected. That took a couple of',
#   'start': 433.199,
#   'duration': 5.44},
#  {'text': 'minutes. So, it is ready.', 'start': 436.08, 'duration': 4.8},
#  {'text': "Let's unpack this. Today, we're diving",
#   'start': 438.639,
#   'duration': 4.721},
#  {'text': 'head first into something, well,',
#   'start': 440.88,
#   'duration': 5.36},
#  {'text': 'something many of us have tried or maybe',
#   'start': 443.36,
#   'duration': 3.92},
#  {'text': 'are trying right now', 'start': 446.24, 'duration': 2.72},
#  {'text': 'or thinking about trying. Yeah,',
#   'start': 447.28,
#   'duration': 4.639},
#  {'text': 'exactly. Learning a new language. So,',
#   'start': 448.96,
#   'duration': 5.04},
#  {'text': "for this deep dive, we've gathered quite",
#   'start': 451.919,
#   'duration': 3.761},
#  {'text': "a stack of sources. We've got stuff from",
#   'start': 454.0,
#   'duration': 4.639},
#  {'text': 'Reddit, uh, real learners, teachers.',
#   'start': 455.68,
#   'duration': 4.32},
#  {'text': "There's some really candid stuff there",
#   'start': 458.639,
#   'duration': 2.801},
#  {'text': 'and a whole heap of opinions on',
#   'start': 460.0,
#   'duration': 3.039},
#  {'text': 'Dualingo. What was it from Tik Tok,',
#   'start': 461.44,
#   'duration': 2.08},
#  {'text': 'actually?', 'start': 463.039, 'duration': 2.801},
#  {'text': 'Ah, Dualingo always sparks a debate,',
#   'start': 463.52,
#   'duration': 3.36},
#  {'text': "doesn't it? Just", 'start': 465.84, 'duration': 2.799},
#  {'text': "All right, let's skip ahead a little",
#   'start': 466.88,
#   'duration': 2.96},
#  {'text': 'bit.', 'start': 468.639, 'duration': 2.96},
#  {'text': 'People repeatedly pointed out it lacks',
#   'start': 469.84,
#   'duration': 2.56},
#  {'text': 'explanations', 'start': 471.599, 'duration': 2.641},
#  {'text': 'on grammar, tenses.', 'start': 472.4, 'duration': 4.0},
#  {'text': 'Exactly. Tenses, grammar, and', 'start': 474.24, 'duration': 3.12},
#  {'text': 'importantly,', 'start': 476.4, 'duration': 2.72},
#  {'text': 'you can actually join this conversation',
#   'start': 477.36,
#   'duration': 3.76},
#  {'text': 'as well. King the interactive mode.',
#   'start': 479.12,
#   'duration': 5.359},
#  {'text': 'Hello. So I wanted to talk a little bit',
#   'start': 481.12,
#   'duration': 3.919},
#  {'text': 'more.', 'start': 484.479, 'duration': 2.16},
#  {'text': 'Well, hey there. Want to share your',
#   'start': 485.039,
#   'duration': 2.401},
#  {'text': 'thoughts on this?', 'start': 486.639, 'duration': 2.801},
#  {'text': 'Yeah. So I want to understand a little',
#   'start': 487.44,
#   'duration': 4.879},
#  {'text': 'bit more what exactly is the primary',
#   'start': 489.44,
#   'duration': 5.12},
#  {'text': 'pain point of using something like dual',
#   'start': 492.319,
#   'duration': 4.401},
#  {'text': 'lane go like what is the singular um',
#   'start': 494.56,
#   'duration': 3.759},
#  {'text': 'issue that people have with it?',
#   'start': 496.72,
#   'duration': 3.12},
#  {'text': 'That is such a great question to start',
#   'start': 498.319,
#   'duration': 3.44},
#  {'text': 'with and it actually really gets to the',
#   'start': 499.84,
#   'duration': 3.759},
#  {'text': 'core of a lot of the feedback we found.',
#   'start': 501.759,
#   'duration': 3.28},
#  {'text': "Yeah, that's really smart to dig into",
#   'start': 503.599,
#   'duration': 3.201},
#  {'text': 'that right away. If we connect this to',
#   'start': 505.039,
#   'duration': 3.6},
#  {'text': 'the bigger picture, the primary pain',
#   'start': 506.8,
#   'duration': 3.839},
#  {'text': "point with Duolingo based on what we've",
#   'start': 508.639,
#   'duration': 4.801},
#  {'text': "seen isn't that it's bad per se,",
#   'start': 510.639,
#   'duration': 4.561},
#  {'text': "right? It's more about what it isn't",
#   'start': 513.44,
#   'duration': 2.8},
#  {'text': 'designed to do.', 'start': 515.2, 'duration': 3.12},
#  {'text': 'Exactly. It excels at things like',
#   'start': 516.24,
#   'duration': 4.56},
#  {'text': 'drilling vocabulary and basic grammar,',
#   'start': 518.32,
#   'duration': 4.56},
#  {'text': 'giving you those consistent snackable',
#   'start': 520.8,
#   'duration': 2.719},
#  {'text': 'lessons,', 'start': 522.88, 'duration': 2.639},
#  {'text': 'which is great for getting started. But',
#   'start': 523.519,
#   'duration': 3.521},
#  {'text': 'the singular issue, the one that keeps',
#   'start': 525.519,
#   'duration': 2.88},
#  {'text': "coming up, is that it doesn't really",
#   'start': 527.04,
#   'duration': 4.08},
#  {'text': 'build conversational fluency or deep',
#   'start': 528.399,
#   'duration': 4.161},
#  {'text': 'understanding of how', 'start': 531.12, 'duration': 4.0},
#  {'text': 'how would using something like AI be',
#   'start': 532.56,
#   'duration': 4.8},
#  {'text': 'able to address these pain points.',
#   'start': 535.12,
#   'duration': 4.08},
#  {'text': 'That is an excellent follow-up question',
#   'start': 537.36,
#   'duration': 3.599},
#  {'text': 'and it really gets to the heart of where',
#   'start': 539.2,
#   'duration': 2.88},
#  {'text': 'edtech is going.', 'start': 540.959, 'duration': 2.56},
#  {'text': "Yeah, that's exactly where we wanted to",
#   'start': 542.08,
#   'duration': 2.48},
#  {'text': 'take the conversation.', 'start': 543.519, 'duration': 3.44},
#  {'text': 'So, if the pain point is the lack of',
#   'start': 544.56,
#   'duration': 4.0},
#  {'text': 'conversational fluency and deeper',
#   'start': 546.959,
#   'duration': 3.841},
#  {'text': 'understanding, AI has some fascinating',
#   'start': 548.56,
#   'duration': 3.04},
#  {'text': 'potential there.', 'start': 550.8, 'duration': 2.64},
#  {'text': 'The sources really highlighted a few key',
#   'start': 551.6,
#   'duration': 4.4},
#  {'text': 'ways. One of the biggest is enabling',
#   'start': 553.44,
#   'duration': 4.56},
#  {'text': 'natural conversation practice.', 'start': 556.0, 'duration': 3.6},
#  {'text': 'Imagine having an AI you can talk to',
#   'start': 558.0,
#   'duration': 2.24},
#  {'text': 'anytime.', 'start': 559.6, 'duration': 2.32},
#  {'text': "A practice buddy, but one that's always",
#   'start': 560.24,
#   'duration': 2.48},
#  {'text': 'available.', 'start': 561.92, 'duration': 2.24},
#  {'text': 'Exactly. One that gives immediate',
#   'start': 562.72,
#   'duration': 3.76},
#  {'text': 'feedback on grammar, carings you gently',
#   'start': 564.16,
#   'duration': 3.2},
#  {'text': 'without judgment.', 'start': 566.48, 'duration': 2.72},
#  {'text': 'Basically, a patient conversation',
#   'start': 567.36,
#   'duration': 4.479},
#  {'text': "partner available 24/7 who won't judge",
#   'start': 569.2,
#   'duration': 3.04},
#  {'text': 'you.', 'start': 571.839, 'duration': 2.161},
#  {'text': 'This directly addresses that fear of',
#   'start': 572.24,
#   'duration': 2.48},
#  {'text': 'looking.', 'start': 574.0, 'duration': 3.12},
#  {'text': "Isn't that just so cool? The first time",
#   'start': 574.72,
#   'duration': 4.88},
#  {'text': 'that I heard this, I was freaking mindb',
#   'start': 577.12,
#   'duration': 4.96},
#  {'text': "blown. This is two AI hosts. It's",
#   'start': 579.6,
#   'duration': 4.72},
#  {'text': "insane, isn't it? So, you can do this. I",
#   'start': 582.08,
#   'duration': 4.08},
#  {'text': "think it's a really great way of really",
#   'start': 584.32,
#   'duration': 4.0},
#  {'text': 'exploring and diving deeper into all of',
#   'start': 586.16,
#   'duration': 3.679},
#  {'text': 'this information, understanding',
#   'start': 588.32,
#   'duration': 3.12},
#  {'text': 'everything much better. And I want to',
#   'start': 589.839,
#   'duration': 3.761},
#  {'text': 'show you now my secret pro tip for how I',
#   'start': 591.44,
#   'duration': 3.92},
#  {'text': 'use audio generation to learn things',
#   'start': 593.6,
#   'duration': 3.359},
#  {'text': "really, really quickly. It's how I keep",
#   'start': 595.36,
#   'duration': 2.8},
#  {'text': 'up with a lot of the AI trends and',
#   'start': 596.959,
#   'duration': 2.241},
#  {'text': "things that are going on. And I'm going",
#   'start': 598.16,
#   'duration': 2.4},
#  {'text': 'to use another example for this cuz',
#   'start': 599.2,
#   'duration': 2.96},
#  {'text': "let's learn about something new. But I",
#   'start': 600.56,
#   'duration': 3.12},
#  {'text': 'do want you to put a bookmark on this',
#   'start': 602.16,
#   'duration': 3.84},
#  {'text': "specific example because we're not just",
#   'start': 603.68,
#   'duration': 3.92},
#  {'text': "going to end it here. I'm actually going",
#   'start': 606.0,
#   'duration': 4.08},
#  {'text': 'to show you how to build out this AI',
#   'start': 607.6,
#   'duration': 4.16},
#  {'text': 'application for learning languages using',
#   'start': 610.08,
#   'duration': 3.6},
#  {'text': 'a combination of notebook and AI',
#   'start': 611.76,
#   'duration': 3.84},
#  {'text': 'assisted coding tools like Firebase',
#   'start': 613.68,
#   'duration': 3.52},
#  {'text': 'Studio, which is also a Google. But',
#   'start': 615.6,
#   'duration': 2.799},
#  {'text': "first, let's cover the core features of",
#   'start': 617.2,
#   'duration': 2.56},
#  {'text': "Notebook LM. All right, here's my pro",
#   'start': 618.399,
#   'duration': 3.201},
#  {'text': 'tip. Are you ready? This is another',
#   'start': 619.76,
#   'duration': 3.759},
#  {'text': "notebook about social media's impact on",
#   'start': 621.6,
#   'duration': 4.08},
#  {'text': 'youth mental health. And I generated an',
#   'start': 623.519,
#   'duration': 4.32},
#  {'text': 'audio overview. We can take a listen to',
#   'start': 625.68,
#   'duration': 4.399},
#  {'text': "this. Welcome to the deep dive. We're",
#   'start': 627.839,
#   'duration': 4.0},
#  {'text': 'here to sift through all the noise, pull',
#   'start': 630.079,
#   'duration': 4.161},
#  {'text': 'out the crucial insights, and well, get',
#   'start': 631.839,
#   'duration': 4.641},
#  {'text': "you properly informed. Today we're",
#   'start': 634.24,
#   'duration': 3.839},
#  {'text': 'diving deep into something that touches',
#   'start': 636.48,
#   'duration': 4.24},
#  {'text': 'almost every family, social media and',
#   'start': 638.079,
#   'duration': 4.32},
#  {'text': 'etc etc which is really great if you',
#   'start': 640.72,
#   'duration': 3.6},
#  {'text': 'want to dive really into this um and',
#   'start': 642.399,
#   'duration': 4.401},
#  {'text': 'really enjoy this process. But sometimes',
#   'start': 644.32,
#   'duration': 4.079},
#  {'text': 'I just need to learn the information',
#   'start': 646.8,
#   'duration': 3.12},
#  {'text': "really really really quickly and there's",
#   'start': 648.399,
#   'duration': 2.961},
#  {'text': 'like a lot of fluff during these',
#   'start': 649.92,
#   'duration': 3.52},
#  {'text': 'podcasts, right? So what I like to do is',
#   'start': 651.36,
#   'duration': 4.32},
#  {'text': 'actually come here and download this',
#   'start': 653.44,
#   'duration': 4.24},
#  {'text': 'audio and put it into Google AI Studio',
#   'start': 655.68,
#   'duration': 3.68},
#  {'text': 'which is also a free tool. Then I ask it',
#   'start': 657.68,
#   'duration': 3.68},
#  {'text': 'to get a transcript of this podcast and',
#   'start': 659.36,
#   'duration': 4.0},
#  {'text': 'then condense it by removing all of the',
#   'start': 661.36,
#   'duration': 4.24},
#  {'text': 'fluff and changing it to a single person',
#   'start': 663.36,
#   'duration': 3.84},
#  {'text': 'as opposed to two people talking. And',
#   'start': 665.6,
#   'duration': 3.52},
#  {'text': 'then I can download it again and play it',
#   'start': 667.2,
#   'duration': 3.84},
#  {'text': 'at 2x 3x speed and get through all of',
#   'start': 669.12,
#   'duration': 2.959},
#  {'text': 'that information super quick.', 'start': 671.04, 'duration': 2.239},
#  {'text': 'The provided text is the growing concern',
#   'start': 672.079,
#   'duration': 2.161},
#  {'text': 'about social media impact on mental',
#   'start': 673.279,
#   'duration': 1.521},
#  {'text': 'health particular.', 'start': 674.24, 'duration': 2.32},
#  {'text': 'And that my friends is my super secret',
#   'start': 674.8,
#   'duration': 3.76},
#  {'text': 'tip on how to learn things really really',
#   'start': 676.56,
#   'duration': 4.08},
#  {'text': 'quickly. Just listen to this while',
#   'start': 678.56,
#   'duration': 3.68},
#  {'text': "you're like running around, you know,",
#   'start': 680.64,
#   'duration': 4.16},
#  {'text': 'going outside, hiking, working out,',
#   'start': 682.24,
#   'duration': 4.96},
#  {'text': 'whatever. And actually, did you know',
#   'start': 684.8,
#   'duration': 4.24},
#  {'text': "that when you're moving around and",
#   'start': 687.2,
#   'duration': 3.84},
#  {'text': 'listening to audio, it helps you',
#   'start': 689.04,
#   'duration': 3.6},
#  {'text': 'concentrate better? Anyways, going back',
#   'start': 691.04,
#   'duration': 3.2},
#  {'text': 'to notebook, I want to show you guys',
#   'start': 692.64,
#   'duration': 3.28},
#  {'text': 'some of the other features that you can',
#   'start': 694.24,
#   'duration': 4.24},
#  {'text': 'use under the studio tab. Um, you can',
#   'start': 695.92,
#   'duration': 4.32},
#  {'text': 'also generate a video overview. So, we',
#   'start': 698.48,
#   'duration': 3.76},
#  {'text': "can have a video over here. And let's",
#   'start': 700.24,
#   'duration': 3.76},
#  {'text': "actually check it out. All right, let's",
#   'start': 702.24,
#   'duration': 3.68},
#  {'text': "talk about something that's well, it's",
#   'start': 704.0,
#   'duration': 4.32},
#  {'text': 'everywhere, right? Social media, teen',
#   'start': 705.92,
#   'duration': 4.64},
#  {'text': 'mental health, you see the headlines all',
#   'start': 708.32,
#   'duration': 4.4},
#  {'text': "the time. But we're going to go a little",
#   'start': 710.56,
#   'duration': 4.719},
#  {'text': 'deeper, get past those headlines, and',
#   'start': 712.72,
#   'duration': 4.88},
#  {'text': "see what's really going on. And it's not",
#   'start': 715.279,
#   'duration': 4.321},
#  {'text': 'just talk. The numbers really back this',
#   'start': 717.6,
#   'duration': 4.72},
#  {'text': 'up. Check this out. The NYC Health',
#   'start': 719.6,
#   'duration': 5.44},
#  {'text': 'Department found that 27% of teens on',
#   'start': 722.32,
#   'duration': 5.84},
#  {'text': 'social media have an anxiety diagnosis.',
#   'start': 725.04,
#   'duration': 5.359},
#  {'text': "Now, compare that to teens who aren't on",
#   'start': 728.16,
#   'duration': 4.479},
#  {'text': 'social media. That number plummets to',
#   'start': 730.399,
#   'duration': 5.12},
#  {'text': "just 9%. We're talking three times",
#   'start': 732.639,
#   'duration': 5.681},
#  {'text': "higher. That's a huge, huge gap. It's",
#   'start': 735.519,
#   'duration': 4.401},
#  {'text': "not just a feeling. It's something",
#   'start': 738.32,
#   'duration': 4.319},
#  {'text': 'health crisis. So boom, the debate just',
#   'start': 739.92,
#   'duration': 5.52},
#  {'text': 'became a fullon legal battle. And look,',
#   'start': 742.639,
#   'duration': 4.241},
#  {'text': "this whole thing didn't just happen",
#   'start': 745.44,
#   'duration': 3.839},
#  {'text': "overnight. It's been building for years.",
#   'start': 746.88,
#   'duration': 5.04},
#  {'text': 'You can trace it back.', 'start': 749.279, 'duration': 5.521},
#  {'text': 'Need I say more? Crazy, right? Oh my',
#   'start': 751.92,
#   'duration': 4.32},
#  {'text': "god, it's crazy. And the graphics that",
#   'start': 754.8,
#   'duration': 3.039},
#  {'text': 'are being generated, they are in fact',
#   'start': 756.24,
#   'duration': 3.279},
#  {'text': 'accurate to what is being represented in',
#   'start': 757.839,
#   'duration': 3.841},
#  {'text': 'the sources as well. Oh my god. Like',
#   'start': 759.519,
#   'duration': 4.161},
#  {'text': 'this is such a game changer. also',
#   'start': 761.68,
#   'duration': 5.2},
#  {'text': "generate a mind map where it's a great",
#   'start': 763.68,
#   'duration': 5.44},
#  {'text': 'way to visualize this information under',
#   'start': 766.88,
#   'duration': 4.0},
#  {'text': 'social media and impact you know you can',
#   'start': 769.12,
#   'duration': 3.6},
#  {'text': 'look at this and then you can actually',
#   'start': 770.88,
#   'duration': 3.92},
#  {'text': 'click in to these different categories',
#   'start': 772.72,
#   'duration': 3.76},
#  {'text': 'as well. So impact on youth mental',
#   'start': 774.8,
#   'duration': 3.76},
#  {'text': 'health adolescent addressing the issue',
#   'start': 776.48,
#   'duration': 3.599},
#  {'text': 'and emotional regulation you can click',
#   'start': 778.56,
#   'duration': 2.719},
#  {'text': "into all of these. So it's a really",
#   'start': 780.079,
#   'duration': 2.721},
#  {'text': 'great way of like visualizing how the',
#   'start': 781.279,
#   'duration': 3.441},
#  {'text': 'data flows together and then in the chat',
#   'start': 782.8,
#   'duration': 4.08},
#  {'text': 'interface it would explain. You can of',
#   'start': 784.72,
#   'duration': 4.4},
#  {'text': 'course also download the mind map looks',
#   'start': 786.88,
#   'duration': 4.0},
#  {'text': 'like this and you can know throw it on a',
#   'start': 789.12,
#   'duration': 3.2},
#  {'text': "slide or something if you're making a",
#   'start': 790.88,
#   'duration': 3.28},
#  {'text': 'presentation about it. And speaking of',
#   'start': 792.32,
#   'duration': 3.28},
#  {'text': 'presentations you can also come here',
#   'start': 794.16,
#   'duration': 3.28},
#  {'text': 'under reports and generate something',
#   'start': 795.6,
#   'duration': 4.0},
#  {'text': 'like a briefing doc very official',
#   'start': 797.44,
#   'duration': 4.399},
#  {'text': 'looking briefing document that you can',
#   'start': 799.6,
#   'duration': 4.72},
#  {'text': 'send to people as an executive summary a',
#   'start': 801.839,
#   'duration': 4.161},
#  {'text': 'study guide. This is pretty similar to',
#   'start': 804.32,
#   'duration': 3.6},
#  {'text': 'the briefing doc in terms of the content',
#   'start': 806.0,
#   'duration': 4.16},
#  {'text': "that's being displayed. But it also has",
#   'start': 807.92,
#   'duration': 4.08},
#  {'text': 'things like a quiz where it would ask',
#   'start': 810.16,
#   'duration': 3.919},
#  {'text': 'you to answer each of these questions in',
#   'start': 812.0,
#   'duration': 3.519},
#  {'text': 'two or three sentences. So this will',
#   'start': 814.079,
#   'duration': 2.88},
#  {'text': 'help you learn things more deeply and it',
#   'start': 815.519,
#   'duration': 3.681},
#  {'text': 'has the answer key as well. Some essay',
#   'start': 816.959,
#   'duration': 4.56},
#  {'text': 'format questions and some glossery of',
#   'start': 819.2,
#   'duration': 4.0},
#  {'text': 'key terms. Something else that you can',
#   'start': 821.519,
#   'duration': 3.76},
#  {'text': 'do is that say you actually want to',
#   'start': 823.2,
#   'duration': 3.92},
#  {'text': 'study this information, you can click',
#   'start': 825.279,
#   'duration': 4.321},
#  {'text': 'convert to source and you can ask a',
#   'start': 827.12,
#   'duration': 4.0},
#  {'text': 'specific questions for the study guide.',
#   'start': 829.6,
#   'duration': 4.239},
#  {'text': 'out like for example extract three quiz',
#   'start': 831.12,
#   'duration': 5.519},
#  {'text': 'questions in the study guide. Yeah. And',
#   'start': 833.839,
#   'duration': 4.24},
#  {'text': 'it says like here are three quiz',
#   'start': 836.639,
#   'duration': 2.801},
#  {'text': 'questions extracted from the study',
#   'start': 838.079,
#   'duration': 3.281},
#  {'text': 'guide. Uh say describe two key',
#   'start': 839.44,
#   'duration': 3.519},
#  {'text': 'characteristics of the adolescent brain',
#   'start': 841.36,
#   'duration': 2.88},
#  {'text': 'that makes it particularly susceptible',
#   'start': 842.959,
#   'duration': 3.361},
#  {'text': 'to the influence of social media. So um',
#   'start': 844.24,
#   'duration': 5.039},
#  {'text': 'I can say like validate if my answer is',
#   'start': 846.32,
#   'duration': 6.319},
#  {'text': 'correct with the answer key is the',
#   'start': 849.279,
#   'duration': 8.56},
#  {'text': 'answer for two key characteristics. I',
#   'start': 852.639,
#   'duration': 6.481},
#  {'text': "actually don't know what it is. I'm just",
#   'start': 857.839,
#   'duration': 4.961},
#  {'text': 'going to like guess here. Uh', 'start': 859.12, 'duration': 8.079},
#  {'text': "maybe it's still developing uh", 'start': 862.8, 'duration': 8.56},
#  {'text': 'decision-m capabilities to differentiate',
#   'start': 867.199,
#   'duration': 8.961},
#  {'text': 'what is real or false. Um is susceptible',
#   'start': 871.36,
#   'duration': 6.88},
#  {'text': 'to emotional', 'start': 876.16, 'duration': 4.32},
#  {'text': "deregulation. I don't know. See that's",
#   'start': 878.24,
#   'duration': 4.399},
#  {'text': 'correct. Uh it does not fully allow the',
#   'start': 880.48,
#   'duration': 3.44},
#  {'text': 'specific key characteristic pride in',
#   'start': 882.639,
#   'duration': 3.76},
#  {'text': 'answer guide. Okay, my bad. Rapid',
#   'start': 883.92,
#   'duration': 6.4},
#  {'text': 'growing and is highly plastic. Uh, and',
#   'start': 886.399,
#   'duration': 5.921},
#  {'text': 'yeah, okay. Well, seems like I need to',
#   'start': 890.32,
#   'duration': 3.92},
#  {'text': 'study more on this subject. But yeah,',
#   'start': 892.32,
#   'duration': 4.4},
#  {'text': 'you can see how this can be extremely',
#   'start': 894.24,
#   'duration': 5.039},
#  {'text': 'powerful if you are actually learning',
#   'start': 896.72,
#   'duration': 4.32},
#  {'text': 'things and want to test yourself. Man,',
#   'start': 899.279,
#   'duration': 3.761},
#  {'text': 'if I had notebook when I was still in',
#   'start': 901.04,
#   'duration': 3.84},
#  {'text': 'college, I I really think I just could',
#   'start': 903.04,
#   'duration': 4.72},
#  {'text': 'have like cut my study time down by 80%',
#   'start': 904.88,
#   'duration': 4.8},
#  {'text': 'probably. So jealous of you guys who are',
#   'start': 907.76,
#   'duration': 3.6},
#  {'text': 'still in school. The timeline feature',
#   'start': 909.68,
#   'duration': 3.599},
#  {'text': 'under reports is also quite useful. If',
#   'start': 911.36,
#   'duration': 3.2},
#  {'text': "for some reason you're interested in",
#   'start': 913.279,
#   'duration': 2.641},
#  {'text': 'learning about the complex world of',
#   'start': 914.56,
#   'duration': 4.16},
#  {'text': 'bananas, you can generate a timeline of',
#   'start': 915.92,
#   'duration': 4.56},
#  {'text': 'the banana development. Very', 'start': 918.72, 'duration': 4.32},
#  {'text': 'fascinating. Prehistory ancient time of',
#   'start': 920.48,
#   'duration': 6.719},
#  {'text': 'banana all the way to the modern banana.',
#   'start': 923.04,
#   'duration': 6.4},
#  {'text': 'Wow. Amazing. Another little pro tip,',
#   'start': 927.199,
#   'duration': 4.64},
#  {'text': 'you can go to Gemini,', 'start': 929.44, 'duration': 5.6},
#  {'text': 'click canvas, copy this detail timeline,',
#   'start': 931.839,
#   'duration': 6.24},
#  {'text': 'and write create an interactive',
#   'start': 935.04,
#   'duration': 4.88},
#  {'text': 'visualization.', 'start': 938.079, 'duration': 4.88},
#  {'text': 'Wow, you have an interactive web',
#   'start': 939.92,
#   'duration': 5.919},
#  {'text': 'application dashboard about the banana',
#   'start': 942.959,
#   'duration': 6.0},
#  {'text': "timeline. Amazing. Gemini doesn't have",
#   'start': 945.839,
#   'duration': 4.961},
#  {'text': "the best like formatting. It's not the",
#   'start': 948.959,
#   'duration': 3.841},
#  {'text': 'most visually appealing one. So, if you',
#   'start': 950.8,
#   'duration': 5.839},
#  {'text': 'do have Claude, copy this. Go to Claude',
#   'start': 952.8,
#   'duration': 7.76},
#  {'text': 'and type create and interactive of this',
#   'start': 956.639,
#   'duration': 5.44},
#  {'text': 'banana', 'start': 960.56, 'duration': 4.48},
#  {'text': 'timeline. Yay! Amazing. The great banana',
#   'start': 962.079,
#   'duration': 4.961},
#  {'text': 'timeline. Wow. From ancient', 'start': 965.04, 'duration': 4.4},
#  {'text': 'domestication to modern crisis. 9,000',
#   'start': 967.04,
#   'duration': 6.08},
#  {'text': 'years of banana history. Wow, so cool.',
#   'start': 969.44,
#   'duration': 6.959},
#  {'text': 'So many banana activities. So, this is a',
#   'start': 973.12,
#   'duration': 5.76},
#  {'text': 'notebook about my AI agents boot camp',
#   'start': 976.399,
#   'duration': 4.8},
#  {'text': 'that we run. The FAQs feature is also',
#   'start': 978.88,
#   'duration': 4.079},
#  {'text': 'quite handy. So, this is the Lonely',
#   'start': 981.199,
#   'duration': 4.08},
#  {'text': 'Octopus AI agent boot camp, um, which',
#   'start': 982.959,
#   'duration': 4.161},
#  {'text': 'looks like this. So, what is quite',
#   'start': 985.279,
#   'duration': 3.041},
#  {'text': 'useful is that you can generate some',
#   'start': 987.12,
#   'duration': 4.0},
#  {'text': 'FAQs that you can put onto your website.',
#   'start': 988.32,
#   'duration': 4.72},
#  {'text': "We've already seen the add notes little",
#   'start': 991.12,
#   'duration': 3.92},
#  {'text': 'button show up a few times now, but I',
#   'start': 993.04,
#   'duration': 4.32},
#  {'text': 'really wanted to emphasize how powerful',
#   'start': 995.04,
#   'duration': 5.12},
#  {'text': 'this button actually is. So, here is a',
#   'start': 997.36,
#   'duration': 4.56},
#  {'text': 'midterm performance review for Bobby',
#   'start': 1000.16,
#   'duration': 4.08},
#  {'text': "Adams, who is a product manager. We're",
#   'start': 1001.92,
#   'duration': 4.719},
#  {'text': "going to paste in some other people's",
#   'start': 1004.24,
#   'duration': 4.88},
#  {'text': 'feedback for Bobby as well. And we are',
#   'start': 1006.639,
#   'duration': 4.961},
#  {'text': 'actually going to generate notes um as',
#   'start': 1009.12,
#   'duration': 4.079},
#  {'text': "we're going through some of this. So,",
#   'start': 1011.6,
#   'duration': 4.32},
#  {'text': 'Laya is a note-taking app. So maybe you',
#   'start': 1013.199,
#   'duration': 4.241},
#  {'text': "know you're looking through Bobby's",
#   'start': 1015.92,
#   'duration': 3.279},
#  {'text': "report and then you're generating notes",
#   'start': 1017.44,
#   'duration': 4.399},
#  {'text': 'like needs to improve communication',
#   'start': 1019.199,
#   'duration': 6.88},
#  {'text': 'skills um is improving technical skill',
#   'start': 1021.839,
#   'duration': 8.561},
#  {'text': 'set and completed goals for Q2 whatever',
#   'start': 1026.079,
#   'duration': 8.161},
#  {'text': 'it is that you want to do like OKRs are',
#   'start': 1030.4,
#   'duration': 8.24},
#  {'text': 'completed feedback from manager is',
#   'start': 1034.24,
#   'duration': 8.16},
#  {'text': 'relative and consider for promotion. So',
#   'start': 1038.64,
#   'duration': 6.08},
#  {'text': "yeah, like as you're going through um",
#   'start': 1042.4,
#   'duration': 3.76},
#  {'text': 'some of these sources and learning more',
#   'start': 1044.72,
#   'duration': 3.04},
#  {'text': 'about it, you can actually add these',
#   'start': 1046.16,
#   'duration': 3.68},
#  {'text': 'notes like evaluate, we can hear in the',
#   'start': 1047.76,
#   'duration': 3.52},
#  {'text': "chat as well, evaluate Bobby Adam's",
#   'start': 1049.84,
#   'duration': 3.92},
#  {'text': 'performance regarding signal signal sync',
#   'start': 1051.28,
#   'duration': 5.12},
#  {'text': "B2. Uh so we're seeing ah like great,",
#   'start': 1053.76,
#   'duration': 4.159},
#  {'text': 'you know, all of this is great as well.',
#   'start': 1056.4,
#   'duration': 3.279},
#  {'text': "So you can save this as a note. It's",
#   'start': 1057.919,
#   'duration': 3.921},
#  {'text': 'generating more information. So what was',
#   'start': 1059.679,
#   'duration': 4.321},
#  {'text': 'a key accomplishment? Save that to',
#   'start': 1061.84,
#   'duration': 5.12},
#  {'text': 'notes. We can generate a timeline of',
#   'start': 1064.0,
#   'duration': 5.52},
#  {'text': "Bobby's. So you see that generate cast",
#   'start': 1066.96,
#   'duration': 4.079},
#  {'text': 'characters, timeline of main events.',
#   'start': 1069.52,
#   'duration': 3.279},
# ...
#   'start': 1404.4,
#   'duration': 2.96},
#  {'text': "going to do now is we're actually going",
#   'start': 1405.919,
#   'duration': 3.281},
#  {'text': 'to distill down this information and',
#   'start': 1407.36,
#   'duration': 4.4},
#  {'text': 'combine these sources together. So the',
#   'start': 1409.2,
#   'duration': 4.16},
#  {'text': 'ones that are for evaluating a startup',
#   'start': 1411.76,
#   'duration': 3.6},
#  {'text': "for example, I'm going to type here",
#   'start': 1413.36,
#   'duration': 5.439},
#  {'text': 'summarize the ways to evaluate what is',
#   'start': 1415.36,
#   'duration': 5.439},
#  {'text': 'considered', 'start': 1418.799, 'duration': 6.961},
#  {'text': 'a good AI app idea. So it has this and',
#   'start': 1420.799,
#   'duration': 7.441},
#  {'text': "what I'm going to do is save this to the",
#   'start': 1425.76,
#   'duration': 5.2},
#  {'text': "note and I'm going to convert this to a",
#   'start': 1428.24,
#   'duration': 4.96},
#  {'text': "source. Then I'm going to do the same",
#   'start': 1430.96,
#   'duration': 5.839},
#  {'text': 'thing for the trends part to summarize',
#   'start': 1433.2,
#   'duration': 9.76},
#  {'text': 'the trends specific to online learning',
#   'start': 1436.799,
#   'duration': 10.281},
#  {'text': 'u for language learning.', 'start': 1442.96, 'duration': 4.12},
#  {'text': "Save that to note as well and we'll add",
#   'start': 1447.12,
#   'duration': 5.76},
#  {'text': 'that as a source. And finally select all',
#   'start': 1449.36,
#   'duration': 6.64},
#  {'text': 'of the user sources. Summarize the user',
#   'start': 1452.88,
#   'duration': 6.159},
#  {'text': 'pain points for online language',
#   'start': 1456.0,
#   'duration': 6.039},
#  {'text': 'learning.', 'start': 1459.039, 'duration': 3.0},
#  {'text': "Now I'm going to select these summarized",
#   'start': 1462.799,
#   'duration': 7.441},
#  {'text': 'sources and write using', 'start': 1466.559, 'duration': 7.281},
#  {'text': 'these selected sources outline the key',
#   'start': 1470.24,
#   'duration': 7.039},
#  {'text': 'features for an AI agent app. So I do',
#   'start': 1473.84,
#   'duration': 5.92},
#  {'text': 'want it to be specifically an AI agent.',
#   'start': 1477.279,
#   'duration': 3.921},
#  {'text': "And if you're not really sure what I",
#   'start': 1479.76,
#   'duration': 2.88},
#  {'text': 'mean by the difference between that,',
#   'start': 1481.2,
#   'duration': 2.8},
#  {'text': 'like what it actually means to be an',
#   'start': 1482.64,
#   'duration': 2.72},
#  {'text': "agent, um I'm not going to go into too",
#   'start': 1484.0,
#   'duration': 2.88},
#  {'text': 'much detail here, but you can check out',
#   'start': 1485.36,
#   'duration': 3.04},
#  {'text': 'this video over here where I explain',
#   'start': 1486.88,
#   'duration': 3.44},
#  {'text': 'specifically what makes an AI agent. But',
#   'start': 1488.4,
#   'duration': 3.04},
#  {'text': 'yeah, I do want this to be like a',
#   'start': 1490.32,
#   'duration': 3.2},
#  {'text': 'vertical AI agent application', 'start': 1491.44, 'duration': 4.96},
#  {'text': 'specifically for language learning. So',
#   'start': 1493.52,
#   'duration': 5.279},
#  {'text': "moment of truth here, we're going to see",
#   'start': 1496.4,
#   'duration': 4.159},
#  {'text': 'what are the key features that would be',
#   'start': 1498.799,
#   'duration': 4.641},
#  {'text': 'required. See, so a good AI agent app',
#   'start': 1500.559,
#   'duration': 4.48},
#  {'text': 'for language learning should incorporate',
#   'start': 1503.44,
#   'duration': 3.28},
#  {'text': 'several key features. All right. So,',
#   'start': 1505.039,
#   'duration': 3.601},
#  {'text': 'real-time conversational practice,',
#   'start': 1506.72,
#   'duration': 4.8},
#  {'text': 'role-play scenario, 247 availability,',
#   'start': 1508.64,
#   'duration': 4.8},
#  {'text': 'safe environment, incident detail',
#   'start': 1511.52,
#   'duration': 3.36},
#  {'text': 'feedback and correction, including',
#   'start': 1513.44,
#   'duration': 3.92},
#  {'text': 'comprehensive error analysis,', 'start': 1514.88, 'duration': 5.6},
#  {'text': 'explanation of mistakes, personalized',
#   'start': 1517.36,
#   'duration': 5.28},
#  {'text': 'reporting, hyperpersonalization, and',
#   'start': 1520.48,
#   'duration': 4.16},
#  {'text': 'adaptive learning path, dynamic',
#   'start': 1522.64,
#   'duration': 3.12},
#  {'text': 'curriculum, blah blah blah. Okay,',
#   'start': 1524.64,
#   'duration': 2.399},
#  {'text': "there's a lot going on here. So what I'm",
#   'start': 1525.76,
#   'duration': 3.279},
#  {'text': "going to say is So I'm going to say I'm",
#   'start': 1527.039,
#   'duration': 4.88},
#  {'text': 'only going to be building an MVP',
#   'start': 1529.039,
#   'duration': 4.961},
#  {'text': 'minimable viable product two core',
#   'start': 1531.919,
#   'duration': 3.76},
#  {'text': 'features that will be the most', 'start': 1534.0, 'duration': 4.24},
#  {'text': 'competitive and suitable for an AI',
#   'start': 1535.679,
#   'duration': 5.041},
#  {'text': 'agent.', 'start': 1538.24, 'duration': 4.48},
#  {'text': 'So it says here it would be real-time',
#   'start': 1540.72,
#   'duration': 4.16},
#  {'text': 'conversational practice and instant',
#   'start': 1542.72,
#   'duration': 4.079},
#  {'text': 'detailed feedback and correction. That',
#   'start': 1544.88,
#   'duration': 3.039},
#  {'text': "seems to be what we're going to be",
#   'start': 1546.799,
#   'duration': 2.721},
#  {'text': 'building. And it has all these sources',
#   'start': 1547.919,
#   'duration': 7.12},
#  {'text': 'here as well. All right, cool. Next,',
#   'start': 1549.52,
#   'duration': 7.36},
#  {'text': 'we are actually going to jump into chat',
#   'start': 1555.039,
#   'duration': 4.321},
#  {'text': "GPT or Gemini if you want. Doesn't",
#   'start': 1556.88,
#   'duration': 4.08},
#  {'text': "actually matter which one. And we're",
#   'start': 1559.36,
#   'duration': 3.52},
#  {'text': "going to input. This is a prompt that's",
#   'start': 1560.96,
#   'duration': 3.92},
#  {'text': 'going to guide us through the process of',
#   'start': 1562.88,
#   'duration': 3.919},
#  {'text': 'thinking even more deeply about the',
#   'start': 1564.88,
#   'duration': 3.679},
#  {'text': 'exact application that we want to be',
#   'start': 1566.799,
#   'duration': 3.76},
#  {'text': 'building. And we want to do this step',
#   'start': 1568.559,
#   'duration': 3.841},
#  {'text': 'before we jump into Firebase Studio, for',
#   'start': 1570.559,
#   'duration': 3.12},
#  {'text': 'example, to actually build out this',
#   'start': 1572.4,
#   'duration': 4.0},
#  {'text': 'application. Because the more clearly',
#   'start': 1573.679,
#   'duration': 4.081},
#  {'text': 'you think through what it is that you',
#   'start': 1576.4,
#   'duration': 3.68},
#  {'text': 'want, the more details that you have and',
#   'start': 1577.76,
#   'duration': 4.159},
#  {'text': 'like what text stack you, what the vibes',
#   'start': 1580.08,
#   'duration': 3.36},
#  {'text': "are that you're going for, what is the",
#   'start': 1581.919,
#   'duration': 3.201},
#  {'text': 'customer experience, what is the user',
#   'start': 1583.44,
#   'duration': 3.52},
#  {'text': 'journey feel like. The more you think',
#   'start': 1585.12,
#   'duration': 3.439},
#  {'text': 'through these things, the better your',
#   'start': 1586.96,
#   'duration': 3.52},
#  {'text': 'end result is going to be. So the first',
#   'start': 1588.559,
#   'duration': 2.961},
#  {'text': 'question to ask is, what are you',
#   'start': 1590.48,
#   'duration': 2.88},
#  {'text': 'building? Can you give me a pitch? And',
#   'start': 1591.52,
#   'duration': 3.84},
#  {'text': 'this is where I am actually going to go',
#   'start': 1593.36,
#   'duration': 5.28},
#  {'text': 'back to Notebook LM and copy what it is',
#   'start': 1595.36,
#   'duration': 4.4},
#  {'text': 'that we just said we were going to',
#   'start': 1598.64,
#   'duration': 4.12},
#  {'text': 'build.', 'start': 1599.76, 'duration': 3.0},
#  {'text': 'Oh, and by the way, um I will be putting',
#   'start': 1603.039,
#   'duration': 4.801},
#  {'text': 'this product requirements prompt in the',
#   'start': 1605.6,
#   'duration': 4.559},
#  {'text': 'description below. So you can just copy',
#   'start': 1607.84,
#   'duration': 4.079},
#  {'text': 'paste that if you want to build it',
#   'start': 1610.159,
#   'duration': 3.361},
#  {'text': "yourself. Anyways, so we're going to",
#   'start': 1611.919,
#   'duration': 3.36},
#  {'text': 'answer the rest of these questions. So',
#   'start': 1613.52,
#   'duration': 4.56},
#  {'text': "what's it for? Who are your users?",
#   'start': 1615.279,
#   'duration': 4.721},
#  {'text': 'So I want to say like beginner to',
#   'start': 1618.08,
#   'duration': 3.839},
#  {'text': 'intermediate', 'start': 1620.0, 'duration': 3.44},
#  {'text': 'languages', 'start': 1621.919, 'duration': 5.281},
#  {'text': 'start with English. This is the easiest',
#   'start': 1623.44,
#   'duration': 5.52},
#  {'text': "there needs. If for example you don't",
#   'start': 1627.2,
#   'duration': 3.52},
#  {'text': 'know like you want to have more detail',
#   'start': 1628.96,
#   'duration': 3.36},
#  {'text': 'you can also keep going back to notebook',
#   'start': 1630.72,
#   'duration': 5.6},
#  {'text': 'LM here and then ask it', 'start': 1632.32, 'duration': 7.56},
#  {'text': 'the questions here.', 'start': 1636.32, 'duration': 3.56},
#  {'text': 'All right.', 'start': 1643.6, 'duration': 3.079},
#  {'text': "It's you know there's a lot of",
#   'start': 1646.799,
#   'duration': 3.12},
#  {'text': "information here but it's okay. It's AI.",
#   'start': 1648.08,
#   'duration': 3.839},
#  {'text': "It can take it. So what's the main user",
#   'start': 1649.919,
#   'duration': 5.36},
#  {'text': 'flow? Can ask that as well. What does',
#   'start': 1651.919,
#   'duration': 6.801},
#  {'text': 'the main user flow look like?',
#   'start': 1655.279,
#   'duration': 6.64},
#  {'text': "So yeah, we can copy that. It's an art",
#   'start': 1658.72,
#   'duration': 4.64},
#  {'text': 'and a science here. You know, sometimes',
#   'start': 1661.919,
#   'duration': 2.801},
#  {'text': 'you want to get it from notebook.',
#   'start': 1663.36,
#   'duration': 2.96},
#  {'text': 'Sometimes you just want to use your own',
#   'start': 1664.72,
#   'duration': 3.839},
#  {'text': 'brain a little bit as well. So what are',
#   'start': 1666.32,
#   'duration': 4.479},
#  {'text': 'the must have features in your MVP? So',
#   'start': 1668.559,
#   'duration': 4.401},
#  {'text': "here's a quick checklist.", 'start': 1670.799, 'duration': 4.88},
#  {'text': "So for now I'm just going to write user",
#   'start': 1672.96,
#   'duration': 4.319},
#  {'text': 'O', 'start': 1675.679, 'duration': 5.041},
#  {'text': 'voice input with speech recognition real',
#   'start': 1677.279,
#   'duration': 7.201},
#  {'text': 'time AI conversation agent feedback',
#   'start': 1680.72,
#   'duration': 5.679},
#  {'text': 'system', 'start': 1684.48, 'duration': 4.4},
#  {'text': 'memory/personalization', 'start': 1686.399, 'duration': 6.361},
#  {'text': 'and push notifications.', 'start': 1688.88, 'duration': 3.88},
#  {'text': 'All right. Now we will copy this. Go',
#   'start': 1697.84,
#   'duration': 7.6},
#  {'text': 'into Firebase Studio and', 'start': 1701.36, 'duration': 6.0},
#  {'text': 'copy this', 'start': 1705.44, 'duration': 6.04},
#  {'text': 'and actually build it.', 'start': 1707.36, 'duration': 4.12},
#  {'text': "I'm not going to show you the full",
#   'start': 1711.52,
#   'duration': 3.2},
#  {'text': 'details of me actually building and',
#   'start': 1712.72,
#   'duration': 3.439},
#  {'text': 'iterating through all of this entire',
#   'start': 1714.72,
#   'duration': 3.04},
#  {'text': 'process because I actually made a full',
#   'start': 1716.159,
#   'duration': 3.441},
#  {'text': "video on Firebase Studio which I'll link",
#   'start': 1717.76,
#   'duration': 3.6},
#  {'text': 'over here um that goes through the',
#   'start': 1719.6,
#   'duration': 3.92},
#  {'text': 'process of building an entire app. which',
#   'start': 1721.36,
#   'duration': 3.76},
#  {'text': 'is really similar to what I did in order',
#   'start': 1723.52,
#   'duration': 6.039},
#  {'text': 'to end up with this application.',
#   'start': 1725.12,
#   'duration': 4.439},
#  {'text': "Hi there. Let's talk about food. What's",
#   'start': 1730.72,
#   'duration': 4.0},
#  {'text': 'on your mind?', 'start': 1733.6, 'duration': 6.76},
#  {'text': 'I like potato. Eating potato.', 'start': 1734.72, 'duration': 5.64},
#  {'text': 'Potatoes are great. Do you have a',
#   'start': 1744.0,
#   'duration': 4.399},
#  {'text': 'favorite way to prepare them?',
#   'start': 1746.799,
#   'duration': 6.36},
#  {'text': 'I like to eat raw potato.', 'start': 1748.399, 'duration': 4.76},
#  {'text': "Raw potato? That's interesting. I've",
#   'start': 1755.12,
#   'duration': 7.88},
#  {'text': 'never tried it that way. Is it crunchy?',
#   'start': 1758.24,
#   'duration': 4.76},
#  {'text': 'Great effort. Keep practicing. It seems',
#   'start': 1764.799,
#   'duration': 5.841},
#  {'text': 'like you repeated potato in your',
#   'start': 1768.159,
#   'duration': 5.12},
#  {'text': 'sentence. To make it flow better, you',
#   'start': 1770.64,
#   'duration': 5.919},
#  {'text': 'could say, "I like eating potatoes."',
#   'start': 1773.279,
#   'duration': 6.081},
#  {'text': "Yay. Isn't that really, really cool? We",
#   'start': 1776.559,
#   'duration': 4.881},
#  {'text': 'literally just went from the very very',
#   'start': 1779.36,
#   'duration': 4.72},
#  {'text': 'beginning to the ideation phase,',
#   'start': 1781.44,
#   'duration': 4.64},
#  {'text': 'analysis, research, all these different',
#   'start': 1784.08,
#   'duration': 4.0},
#  {'text': 'things to an actual functioning',
#   'start': 1786.08,
#   'duration': 3.839},
#  {'text': 'prototype. Pretty cool, huh? Yeah. So,',
#   'start': 1788.08,
#   'duration': 3.68},
#  {'text': 'in this example, I use Firebase Studio',
#   'start': 1789.919,
#   'duration': 3.36},
#  {'text': "because it's free. It's also because it",
#   'start': 1791.76,
#   'duration': 3.279},
#  {'text': "seems like we're sticking mostly to like",
#   'start': 1793.279,
#   'duration': 3.681},
#  {'text': 'Google products since Notebook LM is a',
#   'start': 1795.039,
#   'duration': 3.36},
#  {'text': 'Google product. But really, you can also',
#   'start': 1796.96,
#   'duration': 3.439},
#  {'text': 'use other tools as well. Uh you can have',
#   'start': 1798.399,
#   'duration': 3.76},
#  {'text': 'like you can use Levelable. I also made',
#   'start': 1800.399,
#   'duration': 3.76},
#  {'text': 'a video that goes through how to build',
#   'start': 1802.159,
#   'duration': 3.601},
#  {'text': 'um applications using Levelable, which I',
#   'start': 1804.159,
#   'duration': 3.12},
#  {'text': 'will link over here. And if you are a',
#   'start': 1805.76,
#   'duration': 2.88},
#  {'text': "technical person and you're comfortable",
#   'start': 1807.279,
#   'duration': 3.041},
#  {'text': 'with code, you can also start building',
#   'start': 1808.64,
#   'duration': 4.72},
#  {'text': 'it out using claude code which I do have',
#   'start': 1810.32,
#   'duration': 6.479},
#  {'text': 'a video about here as well. So yeah.',
#   'start': 1813.36,
#   'duration': 4.64},
#  {'text': 'Okay. Thank you so much for watching',
#   'start': 1816.799,
#   'duration': 2.641},
#  {'text': 'until the end of this video. I really',
#   'start': 1818.0,
#   'duration': 3.76},
#  {'text': 'hope this was helpful for you in',
#   'start': 1819.44,
#   'duration': 4.32},
#  {'text': 'learning more about Notebook LM and just',
#   'start': 1821.76,
#   'duration': 4.24},
#  {'text': 'realizing how crazy powerful it is,',
#   'start': 1823.76,
#   'duration': 4.399},
#  {'text': 'right? Uh so as promised, here is a',
#   'start': 1826.0,
#   'duration': 4.0},
#  {'text': 'little assessment. Please answer these',
#   'start': 1828.159,
#   'duration': 3.76},
#  {'text': 'questions and put them in the comments',
#   'start': 1830.0,
#   'duration': 3.6},
#  {'text': 'so you can actually retain all the',
#   'start': 1831.919,
#   'duration': 4.081},
#  {'text': 'information that we covered today. Thank',
#   'start': 1833.6,
#   'duration': 4.24},
#  {'text': 'you so much and I will see you guys in',
#   'start': 1836.0,
#   'duration': 6.279},
#  {'text': 'the next video or live stream.',
#   'start': 1837.84,
#   'duration': 4.439}]

# %% [markdown]
# ### Indexing (Chunking)

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

splitter=RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200
)
chunks=splitter.split_text(transcript)

# %%
len(chunks)
# Out:
# 41

# %%
chunks[0]
# Out:
# "I learned how to use Notebook LM for you. So, here's the Cliffnotes version to save you the hours and hours that I've spent deep diving into this extremely powerful tool for both working and learning. It is honestly one of my favorite tools, and it's crazy how much value you get from the free version. So, in this video, I'm going to show you the core features of Notebook Outlook, including things like distilling and summarizing information and how to make it even more powerful in combination with other tools to even do things like automating workflows and building AI products. As per usual, it is not enough for you just to listen to me talk about stuff. So throughout this video, I will have little assessments which if you can answer these questions, then congratulations. You would be educated on using Notebook LM. Now, without further ado, let's go. A portion of this video is sponsored by Augen Code. Let's start off with first answering the question, what is Notebook LM for? Well, if"

# %% [markdown]
# ## Embeddings and vector_store

# %%
type(chunks[0])
# Out:
# str

# %%
import os
from dotenv import load_dotenv
from langchain_huggingface import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS

load_dotenv()
huggingface_api=os.getenv("HUGGINGFACEHUB_ACCESS_TOKEN")

embeddings=HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

vector_store=FAISS.from_texts(chunks,embedding=embeddings)

# %%
vector_store.index_to_docstore_id
# Out:
# {0: 'a11184bc-1e25-43c1-beec-12548bcac220',
#  1: '04177a40-6adf-4c0e-a890-1e7114a48b73',
#  2: 'db7caa66-83a7-48fc-bdb8-800c45be694e',
#  3: 'c94f96ee-58c4-40d5-8adb-2176fab6c8ff',
#  4: '29f4b6dd-3bb3-488b-a88a-860c96077e5f',
#  5: '0aa35e5f-8e70-428f-8ccb-d05b15f569e3',
#  6: 'f421bba5-97b8-4b8b-8cee-55eb8cacfec6',
#  7: '739de02c-614d-44b8-81f6-c03b07791df0',
#  8: '7299e759-0d7a-442f-8b20-11ce3e281c04',
#  9: '3af3444d-7c26-43e5-91fd-033556c768f5',
#  10: '3337c8e3-de63-404b-89b6-86f0053bb371',
#  11: '556d512c-457d-4ac3-8f40-b8f5e775f993',
#  12: '95316c19-64ad-49e7-86be-a1238dd2ec41',
#  13: 'f6006bcf-bd1d-4783-adc6-c3b7b265b6f6',
#  14: 'fd522b64-f80c-4d7a-b419-02b401cf58a1',
#  15: 'cbb0405d-43ca-4b65-97af-742c7159b5b9',
#  16: 'ce5b3ad4-3bc9-49c8-8114-75fb98b30ab8',
#  17: '0f0f06c2-a4c7-4114-8a70-0b4723e9bef5',
#  18: 'b05a71fd-664d-4f0a-9636-f1857f9cc658',
#  19: 'c8c38d9b-4f9a-458f-b58c-a1179e34b5ab',
#  20: '57ddf17d-87de-4fbd-b2fc-f26b62e04706',
#  21: '0be6a57e-4fc5-42b2-a8ec-b7aa467e2d2e',
#  22: '95a816cd-dcda-42a5-a3d6-2ef42583e2b4',
#  23: 'b8ab3f86-e7d1-4e33-8df0-dafb17398f0c',
#  24: 'eccd8a50-6f6b-4c6b-821b-7f7774435403',
#  25: '54e2d7a7-0419-41a0-aad2-8d0201506162',
#  26: '90b545a4-cc58-4e70-844a-fa81d052e12f',
#  27: '33702bf6-7750-4f7e-96a8-f0a8194cc7ac',
#  28: 'bab0442a-98fa-4282-8904-e282b398e03a',
#  29: '0566a1b1-5da5-4fdc-97cf-8f49cf79fbc1',
#  30: '2237f163-29d5-4c09-ada9-f9b06357ffc7',
#  31: '6734788f-0ac2-49b0-9b6f-1bb1f1092537',
#  32: '062b09be-245b-408f-9904-ff9f9f1962f5',
#  33: 'cd689610-20b8-438f-bd7c-7ca54e8ce1b0',
#  34: '414dc04b-a7e2-47c9-a6e5-89f669eae8f6',
#  35: '173fa2f7-68a3-4106-b3d4-8fb0d3743c34',
#  36: '6d2f3260-4cb6-43a5-bab2-0767104a47c9',
#  37: '6abee88e-2918-488c-bb81-b322565c16b9',
#  38: '75a4f969-69fc-4393-85ba-84db66e5e243',
#  39: 'd360fe48-9749-4022-9fd2-8192992c039a',
#  40: '21d04fac-5eca-4888-a5f4-01062ff39d14'}

# %%
vector_store.get_by_ids(['bf613bbb-cbfd-4eda-9b81-81bcf109fa35'])
# Out:
# []

# %% [markdown]
# ### Retriever

# %%
retreiver=vector_store.as_retriever(search_type="mmr",search_kwargs={"k":5,"lambda_mult":0.5})

# %%
retreiver.invoke("What are LLM notebooks")
# Out:
# [Document(id='db7caa66-83a7-48fc-bdb8-800c45be694e', metadata={}, page_content="Notebook Lab. When you first go into Notebook LM and you click create a new notebook, step number one is to upload your sources. You can drag and drop all sorts of different files and also link from your Google Drive, different links including websites and YouTube links and copy text as well. You can also click to discover sources tab and be able to search other external sources too. You can then chat with your sources in this chat window asking you to do things like summarizing or analyzing. But that's not all. What really makes Notebook LM stand out are these specialized sources here under studio to help you dive deeper into the content and to understand it better, including things like generating an audio overview, generating an AI podcast. Today, we're diving headirst into something which is what first made Notebook LM go viral, and also do video overviews, mind maps, and all sorts of reports. I'll be showing you examples of these all in a bit, and it is really, really cool. As"),
#  Document(id='90b545a4-cc58-4e70-844a-fa81d052e12f', metadata={}, page_content="app is, you can still ship incredibly fast with Augment. You can even launch cloud agents to refactor or fix tests while your laptop is closed. It runs in your IDE including VS Code, Jet Brains, Vim, and Cursor. And it's secure. Augment is ISO and SOCK 2 certified. And there's no training on customer code ever. You can try it out 7 days for free at the link in the description. Thank you so much Augment Code for sponsoring this portion of the video. Now back to the video. All right, before I show you how to combine Notebook LM with other applications to make it even more powerful, I just want to briefly cover the additional features that you can get if you do have the paid version of Notebook LM. As I said earlier, you really already get so much just from the free version alone. But there are like a few perks. So there's three different levels. There's the free tier, DC pro tier, and then there's the enterprise tier. And some of the things that you do get on the pro tier is that here"),
#  Document(id='b8ab3f86-e7d1-4e33-8df0-dafb17398f0c', metadata={}, page_content="We've already seen the add notes little button show up a few times now, but I really wanted to emphasize how powerful this button actually is. So, here is a midterm performance review for Bobby Adams, who is a product manager. We're going to paste in some other people's feedback for Bobby as well. And we are actually going to generate notes um as we're going through some of this. So, Laya is a note-taking app. So maybe you know you're looking through Bobby's report and then you're generating notes like needs to improve communication skills um is improving technical skill set and completed goals for Q2 whatever it is that you want to do like OKRs are completed feedback from manager is relative and consider for promotion. So yeah, like as you're going through um some of these sources and learning more about it, you can actually add these notes like evaluate, we can hear in the chat as well, evaluate Bobby Adam's performance regarding signal signal sync B2. Uh so we're seeing ah like"),
#  Document(id='0566a1b1-5da5-4fdc-97cf-8f49cf79fbc1', metadata={}, page_content="just get more security like privacy and security guarantees from it. So, in terms of the actual pricing models, it seems like you don't really purchase it um by itself. You really just purchase it based upon the package of which Google product that you have. So, in my case, I get the pro um version because I have Google Workspace for business. Okay, let's now talk about Notebook LM in combination with other applications. One of my favorite combinations is between Notebook LM and deep research. So using deep research, I would generate something that is of deep dive into a specific topic and then I would add that as a source into Notebook LM. For example, looking at very specific market trends for electric vehicles in Malaysia between a time of 2020 to 2025. I would just add that as a source in addition to all the other sources because after all you know with all the different bells and whistles that notebook LM has really the key thing like everything that is grounded with is the"),
#  Document(id='bab0442a-98fa-4282-8904-e282b398e03a', metadata={}, page_content="of a difference, I would say. Um yeah, I I don't think it really makes too big of a difference. Anyways, you do also have the share tab over here. So, this is when you can add other people um into this notebook and you can share them with them. You can also add a little welcome note like for example like hello check out you know something like that and you can give a different access like between full notebook and chat only and copy link and just paste the link to them. You also get analytics. Um so here I don't have any analytics because you need to share with at least four other users to see what the uh chat activity is but you would be able to see analytics across different users as well. And finally, there is enterprise level as well where you pretty much get all these features, but you just get more security like privacy and security guarantees from it. So, in terms of the actual pricing models, it seems like you don't really purchase it um by itself. You really just purchase it")]

# %% [markdown]
# ### Augmentation

# %%
from langchain_huggingface import HuggingFaceEndpoint,ChatHuggingFace

llm=HuggingFaceEndpoint(
    repo_id="openai/gpt-oss-120b",task="conversational",huggingfacehub_api_token=huggingface_api
)
chat_model=ChatHuggingFace(llm=llm)

# %%
from langchain.prompts import PromptTemplate

template=PromptTemplate(
    template="""
      You are a helpful assistant.
      Answer ONLY from the provided transcript context.
      If the context is insufficient, just say you don't know.

      {context}
      Question: {question}
    """,
    input_variables=["context","question"]
)

# %%
question          = "is the topic of LLM notebooks was discussed in the video ? If yes what was discussed"
retrieved_docs    = retreiver.invoke(question)

# %%
retrieved_docs[0]
# Out:
# Document(id='db7caa66-83a7-48fc-bdb8-800c45be694e', metadata={}, page_content="Notebook Lab. When you first go into Notebook LM and you click create a new notebook, step number one is to upload your sources. You can drag and drop all sorts of different files and also link from your Google Drive, different links including websites and YouTube links and copy text as well. You can also click to discover sources tab and be able to search other external sources too. You can then chat with your sources in this chat window asking you to do things like summarizing or analyzing. But that's not all. What really makes Notebook LM stand out are these specialized sources here under studio to help you dive deeper into the content and to understand it better, including things like generating an audio overview, generating an AI podcast. Today, we're diving headirst into something which is what first made Notebook LM go viral, and also do video overviews, mind maps, and all sorts of reports. I'll be showing you examples of these all in a bit, and it is really, really cool. As")

# %%
context_text="\n\n".join(doc.page_content for doc in retrieved_docs)

# %%
print(context_text)
# Out:
# Notebook Lab. When you first go into Notebook LM and you click create a new notebook, step number one is to upload your sources. You can drag and drop all sorts of different files and also link from your Google Drive, different links including websites and YouTube links and copy text as well. You can also click to discover sources tab and be able to search other external sources too. You can then chat with your sources in this chat window asking you to do things like summarizing or analyzing. But that's not all. What really makes Notebook LM stand out are these specialized sources here under studio to help you dive deeper into the content and to understand it better, including things like generating an audio overview, generating an AI podcast. Today, we're diving headirst into something which is what first made Notebook LM go viral, and also do video overviews, mind maps, and all sorts of reports. I'll be showing you examples of these all in a bit, and it is really, really cool. As
#
# powerful it is, right? Uh so as promised, here is a little assessment. Please answer these questions and put them in the comments so you can actually retain all the information that we covered today. Thank you so much and I will see you guys in the next video or live stream.
#
# copy this detail timeline, and write create an interactive visualization. Wow, you have an interactive web application dashboard about the banana timeline. Amazing. Gemini doesn't have the best like formatting. It's not the most visually appealing one. So, if you do have Claude, copy this. Go to Claude and type create and interactive of this banana timeline. Yay! Amazing. The great banana timeline. Wow. From ancient domestication to modern crisis. 9,000 years of banana history. Wow, so cool. So many banana activities. So, this is a notebook about my AI agents boot camp that we run. The FAQs feature is also quite handy. So, this is the Lonely Octopus AI agent boot camp, um, which looks like this. So, what is quite useful is that you can generate some FAQs that you can put onto your website. We've already seen the add notes little button show up a few times now, but I really wanted to emphasize how powerful this button actually is. So, here is a midterm performance review for Bobby
#
# app is, you can still ship incredibly fast with Augment. You can even launch cloud agents to refactor or fix tests while your laptop is closed. It runs in your IDE including VS Code, Jet Brains, Vim, and Cursor. And it's secure. Augment is ISO and SOCK 2 certified. And there's no training on customer code ever. You can try it out 7 days for free at the link in the description. Thank you so much Augment Code for sponsoring this portion of the video. Now back to the video. All right, before I show you how to combine Notebook LM with other applications to make it even more powerful, I just want to briefly cover the additional features that you can get if you do have the paid version of Notebook LM. As I said earlier, you really already get so much just from the free version alone. But there are like a few perks. So there's three different levels. There's the free tier, DC pro tier, and then there's the enterprise tier. And some of the things that you do get on the pro tier is that here
#
# of a difference, I would say. Um yeah, I I don't think it really makes too big of a difference. Anyways, you do also have the share tab over here. So, this is when you can add other people um into this notebook and you can share them with them. You can also add a little welcome note like for example like hello check out you know something like that and you can give a different access like between full notebook and chat only and copy link and just paste the link to them. You also get analytics. Um so here I don't have any analytics because you need to share with at least four other users to see what the uh chat activity is but you would be able to see analytics across different users as well. And finally, there is enterprise level as well where you pretty much get all these features, but you just get more security like privacy and security guarantees from it. So, in terms of the actual pricing models, it seems like you don't really purchase it um by itself. You really just purchase it

# %%
final_prompt=template.invoke({
    "context": context_text,
    "question": question
})

# %%
final_prompt
# Out:
# StringPromptValue(text="\n      You are a helpful assistant.\n      Answer ONLY from the provided transcript context.\n      If the context is insufficient, just say you don't know.\n\n      Notebook Lab. When you first go into Notebook LM and you click create a new notebook, step number one is to upload your sources. You can drag and drop all sorts of different files and also link from your Google Drive, different links including websites and YouTube links and copy text as well. You can also click to discover sources tab and be able to search other external sources too. You can then chat with your sources in this chat window asking you to do things like summarizing or analyzing. But that's not all. What really makes Notebook LM stand out are these specialized sources here under studio to help you dive deeper into the content and to understand it better, including things like generating an audio overview, generating an AI podcast. Today, we're diving headirst into something which is what first made Notebook LM go viral, and also do video overviews, mind maps, and all sorts of reports. I'll be showing you examples of these all in a bit, and it is really, really cool. As\n\npowerful it is, right? Uh so as promised, here is a little assessment. Please answer these questions and put them in the comments so you can actually retain all the information that we covered today. Thank you so much and I will see you guys in the next video or live stream.\n\ncopy this detail timeline, and write create an interactive visualization. Wow, you have an interactive web application dashboard about the banana timeline. Amazing. Gemini doesn't have the best like formatting. It's not the most visually appealing one. So, if you do have Claude, copy this. Go to Claude and type create and interactive of this banana timeline. Yay! Amazing. The great banana timeline. Wow. From ancient domestication to modern crisis. 9,000 years of banana history. Wow, so cool. So many banana activities. So, this is a notebook about my AI agents boot camp that we run. The FAQs feature is also quite handy. So, this is the Lonely Octopus AI agent boot camp, um, which looks like this. So, what is quite useful is that you can generate some FAQs that you can put onto your website. We've already seen the add notes little button show up a few times now, but I really wanted to emphasize how powerful this button actually is. So, here is a midterm performance review for Bobby\n\napp is, you can still ship incredibly fast with Augment. You can even launch cloud agents to refactor or fix tests while your laptop is closed. It runs in your IDE including VS Code, Jet Brains, Vim, and Cursor. And it's secure. Augment is ISO and SOCK 2 certified. And there's no training on customer code ever. You can try it out 7 days for free at the link in the description. Thank you so much Augment Code for sponsoring this portion of the video. Now back to the video. All right, before I show you how to combine Notebook LM with other applications to make it even more powerful, I just want to briefly cover the additional features that you can get if you do have the paid version of Notebook LM. As I said earlier, you really already get so much just from the free version alone. But there are like a few perks. So there's three different levels. There's the free tier, DC pro tier, and then there's the enterprise tier. And some of the things that you do get on the pro tier is that here\n\nof a difference, I would say. Um yeah, I I don't think it really makes too big of a difference. Anyways, you do also have the share tab over here. So, this is when you can add other people um into this notebook and you can share them with them. You can also add a little welcome note like for example like hello check out you know something like that and you can give a different access like between full notebook and chat only and copy link and just paste the link to them. You also get analytics. Um so here I don't have any anal ...

# %% [markdown]
# ### Generation

# %%
answer = chat_model.invoke(final_prompt)
print(answer.content)
# Out:
# Yes. The video spent a good portion of its time talking about **Notebook LM (the LLM notebook platform)** and its capabilities.
#
# **What was discussed:**
#
# - **Creating a new notebook** – the first step is uploading sources (files, Google‑Drive links, websites, YouTube links, copied text) or discovering external sources via the “Discover sources” tab.
# - **Chatting with the sources** – you can ask the notebook to summarize, analyze, etc.
# - **Specialized “studio” sources** – tools that let you generate audio overviews, AI podcasts, video overviews, mind‑maps, and various reports.
# - **Interactive visualizations** – example of an interactive web‑dashboard for a “banana timeline” (creating it via Claude or Gemini).
# - **FAQ generation** – demonstrated with the “Lonely Octopus AI agent boot camp” notebook, showing how to produce FAQs for a website.
# - **Add‑notes button** – highlighted as a powerful feature for inserting notes.
# - **Augment integration** – launch cloud agents to refactor or fix tests directly from the IDE (VS Code, JetBrains, Vim, Cursor), with ISO and SOC‑2 security.
# - **Paid‑tier features** – three tiers (Free, Pro, Enterprise). Pro adds sharing options (invite others, set access levels, welcome notes), analytics (chat activity across users), and more. Enterprise adds extra privacy and security guarantees.
#
# So the video indeed covered the topic of LLM notebooks, focusing on how Notebook LM works, its free‑vs‑paid features, and several practical use‑cases.

# %% [markdown]
# ## Building a chain

# %%
from langchain_core.runnables import RunnableParallel, RunnablePassthrough, RunnableLambda
from langchain_core.output_parsers import StrOutputParser

# %%
def format_docs(retrieved_docs):
  context_text = "\n\n".join(doc.page_content for doc in retrieved_docs)
  return context_text

# %%
parallel_chain = RunnableParallel({
    'context': retreiver | RunnableLambda(format_docs),
    'question': RunnablePassthrough()
})

# %%
parallel_chain.invoke("Hello")
# Out:
# {'context': "about trying. Yeah, exactly. Learning a new language. So, for this deep dive, we've gathered quite a stack of sources. We've got stuff from Reddit, uh, real learners, teachers. There's some really candid stuff there and a whole heap of opinions on Dualingo. What was it from Tik Tok, actually? Ah, Dualingo always sparks a debate, doesn't it? Just All right, let's skip ahead a little bit. People repeatedly pointed out it lacks explanations on grammar, tenses. Exactly. Tenses, grammar, and importantly, you can actually join this conversation as well. King the interactive mode. Hello. So I wanted to talk a little bit more. Well, hey there. Want to share your thoughts on this? Yeah. So I want to understand a little bit more what exactly is the primary pain point of using something like dual lane go like what is the singular um issue that people have with it? That is such a great question to start with and it actually really gets to the core of a lot of the feedback we found. Yeah, that's\n\ncover the core features of Notebook LM. All right, here's my pro tip. Are you ready? This is another notebook about social media's impact on youth mental health. And I generated an audio overview. We can take a listen to this. Welcome to the deep dive. We're here to sift through all the noise, pull out the crucial insights, and well, get you properly informed. Today we're diving deep into something that touches almost every family, social media and etc etc which is really great if you want to dive really into this um and really enjoy this process. But sometimes I just need to learn the information really really really quickly and there's like a lot of fluff during these podcasts, right? So what I like to do is actually come here and download this audio and put it into Google AI Studio which is also a free tool. Then I ask it to get a transcript of this podcast and then condense it by removing all of the fluff and changing it to a single person as opposed to two people talking. And\n\npowerful it is, right? Uh so as promised, here is a little assessment. Please answer these questions and put them in the comments so you can actually retain all the information that we covered today. Thank you so much and I will see you guys in the next video or live stream.\n\ndetailed feedback and correction. That seems to be what we're going to be building. And it has all these sources here as well. All right, cool. Next, we are actually going to jump into chat GPT or Gemini if you want. Doesn't actually matter which one. And we're going to input. This is a prompt that's going to guide us through the process of thinking even more deeply about the exact application that we want to be building. And we want to do this step before we jump into Firebase Studio, for example, to actually build out this application. Because the more clearly you think through what it is that you want, the more details that you have and like what text stack you, what the vibes are that you're going for, what is the customer experience, what is the user journey feel like. The more you think through these things, the better your end result is going to be. So the first question to ask is, what are you building? Can you give me a pitch? And this is where I am actually going to go back\n\ncopy this detail timeline, and write create an interactive visualization. Wow, you have an interactive web application dashboard about the banana timeline. Amazing. Gemini doesn't have the best like formatting. It's not the most visually appealing one. So, if you do have Claude, copy this. Go to Claude and type create and interactive of this banana timeline. Yay! Amazing. The great banana timeline. Wow. From ancient domestication to modern crisis. 9,000 years of banana history. Wow, so cool. So many banana activities. So, this is a notebook about my AI agents boot camp that we run. The FAQs feature is also quite handy. So, this is the Lonely Octopus AI agent boot camp, um, which looks like this. S ...
#  'question': 'Hello'}

# %%
parser = StrOutputParser()

# %%
main_chain = parallel_chain | template | llm | parser

# %%
main_chain.invoke('extract key points')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 main_chain.invoke('extract key points')
#
# File c:\Users\mudas\OneDrive\Desktop\Langchain\my_env\Lib\site-packages\langchain_core\runnables\base.py:3049, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3047                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3048             else:
# -> 3049                 input_ = context.run(step.invoke, input_, config)
#    3050 # finish the root run
#    3051 except BaseException as e:
#
# File c:\Users\mudas\OneDrive\Desktop\Langchain\my_env\Lib\site-packages\langchain_core\language_models\llms.py:389, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     378 @override
#     379 def invoke(
#     380     self,
#    (...)    385     **kwargs: Any,
#     386 ) -> str:
#     387     config = ensure_config(config)
#     388     return (
# --> 389         self.generate_prompt(
#     390             [self._convert_input(input)],
#     391             stop=stop,
#     392             callbacks=config.get("callbacks"),
#     393             tags=config.get("tags"),
#     394             metadata=config.get("metadata"),
#     395             run_name=config.get("run_name"),
#     396             run_id=config.pop("run_id", None),
#     397             **kwargs,
#     398         )
#     399         .generations[0][0]
#     400         .text
#     401     )
#
# File c:\Users\mudas\OneDrive\Desktop\Langchain\my_env\Lib\site-packages\langchain_core\language_models\llms.py:766, in BaseLLM.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     757 @override
#     758 def generate_prompt(
#     759     self,
#    (...)    763     **kwargs: Any,
#     764 ) -> LLMResult:
#     765     prompt_strings = [p.to_string() for p in prompts]
# --> 766     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\mudas\OneDrive\Desktop\Langchain\my_env\Lib\site-packages\langchain_core\language_models\llms.py:971, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     956 if (self.cache is None and get_llm_cache() is None) or self.cache is False:
#     957     run_managers = [
#     958         callback_manager.on_llm_start(
#     959             self._serialized,
#    (...)    969         )
#     970     ]
# --> 971     return self._generate_helper(
#     972         prompts,
#     973         stop,
#     974         run_managers,
#     975         new_arg_supported=bool(new_arg_supported),
#     976         **kwargs,
#     977     )
#     978 if len(missing_prompts) > 0:
#     979     run_managers = [
#     980         callback_managers[idx].on_llm_start(
#     981             self._serialized,
#    (...)    988         for idx in missing_prompt_idxs
#     989     ]
#
# File c:\Users\mudas\OneDrive\Desktop\Langchain\my_env\Lib\site-packages\langchain_core\language_models\llms.py:792, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     781 def _generate_helper(
#     782     self,
#     783     prompts: list[str],
#    (...)    788     **kwargs: Any,
#     789 ) -> LLMResult:
#     790     try:
#     791         output = (
# --> 792             self._generate(
#     793                 prompts,
#     794                 stop=stop,
#     795                 # TODO: support multiple run managers
#     796                 run_manager=run_managers[0] if run_managers else None,
#     797                 **kwargs,
#     798             )
#     799             if new_arg_supported
#     800             else self._generate(prompts, stop=stop)
#     801         )
#     802     except BaseException as e:
#     803         for run_manager in run_managers:
#
# File c:\Users\mudas\OneDrive\Desktop\Langchain\my_env\Lib\site-packages\langchain_core\language_models\llms.py:1545, in LLM._generate(self, prompts, stop, run_manager, **kwargs)
#    1542 new_arg_supported = inspect.signature(self._call).parameters.get("run_manager")
#    1543 for prompt in prompts:
#    1544     text = (
# -> 1545         self._call(prompt, stop=stop, run_manager=run_manager, **kwargs)
#    1546         if new_arg_supported
#    1547         else self._call(prompt, stop=stop, **kwargs)
#    1548     )
#    1549     generations.append([Generation(text=text)])
#    1550 return LLMResult(generations=generations)
#
# File c:\Users\mudas\OneDrive\Desktop\Langchain\my_env\Lib\site-packages\langchain_huggingface\llms\huggingface_endpoint.py:318, in HuggingFaceEndpoint._call(self, prompt, stop, run_manager, **kwargs)
#     315         completion += chunk.text
#     316     return completion
# --> 318 response_text = self.client.text_generation(
#     319     prompt=prompt,
#     320     model=self.model,
#     321     **invocation_params,
#     322 )
#     324 # Maybe the generation has stopped at one of the stop sequences:
#     325 # then we remove this stop sequence from the end of the generated text
#     326 for stop_seq in invocation_params["stop"]:
#
# File c:\Users\mudas\OneDrive\Desktop\Langchain\my_env\Lib\site-packages\huggingface_hub\inference\_client.py:2375, in InferenceClient.text_generation(self, prompt, details, stream, model, adapter_id, best_of, decoder_input_details, do_sample, frequency_penalty, grammar, max_new_tokens, repetition_penalty, return_full_text, seed, stop, stop_sequences, temperature, top_k, top_n_tokens, top_p, truncate, typical_p, watermark)
#    2369         raise ValueError(
#    2370             "API endpoint/model for text-generation is not served via TGI. Cannot return output as a stream."
#    2371             " Please pass `stream=False` as input."
#    2372         )
#    2374 model_id = model or self.model
# -> 2375 provider_helper = get_provider_helper(self.provider, task="text-generation", model=model_id)
#    2376 request_parameters = provider_helper.prepare_request(
#    2377     inputs=prompt,
#    2378     parameters=parameters,
#    (...)   2382     api_key=self.token,
#    2383 )
#    2385 # Handle errors separately for more precise error messages
#
# File c:\Users\mudas\OneDrive\Desktop\Langchain\my_env\Lib\site-packages\huggingface_hub\inference\_providers\__init__.py:207, in get_provider_helper(provider, task, model)
#     200     raise ValueError(
#     201         f"Provider '{provider}' not supported. Available values: 'auto' or any provider from {list(PROVIDERS.keys())}."
#     202         "Passing 'auto' (default value) will automatically select the first provider available for the model, sorted "
#     203         "by the user's order in https://hf.co/settings/inference-providers."
#     204     )
#     206 if task not in provider_tasks:
# --> 207     raise ValueError(
#     208         f"Task '{task}' not supported for provider '{provider}'. Available tasks: {list(provider_tasks.keys())}"
#     209     )
#     210 return provider_tasks[task]
#
# ValueError: Task 'text-generation' not supported for provider 'fireworks-ai'. Available tasks: ['conversational']
